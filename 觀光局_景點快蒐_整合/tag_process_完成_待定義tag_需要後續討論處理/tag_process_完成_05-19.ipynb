# %%
import pandas as pd 
data = pd.read_csv('C:/Users/csie/Downloads/景點資料合併/tag_process_完成_待定義tag_需要後續討論處理.csv')

# %%
data
# Out:
#              Location        Location_tag_final
# 0                  九份             #逛老街#賞夜景#非吃不可
# 1                  淡水                 #逛老街#非吃不可
# 2                士林夜市            #打卡熱點#非吃不可#逛夜市
# 3              野柳地質公園        #地質奇觀#打卡熱點#拍婚紗#無障礙
# 4                  旗津       #打卡熱點#夏天戲水#單車漫遊#逛老街
# 5             陽明山國家公園        #賞花#登山步道#泡溫泉#國家風景區
# 6                  烏來                  #泡溫泉#逛老街
# 7                 西子灣       #浪漫約會#送夕陽#親子共遊#夏天戲水
# 8             國立故宮博物院             #看展覽#博物館#親子共遊
# 9               臺北龍山寺           #寺廟祈福#打卡熱點#古蹟巡禮
# 10                蓮池潭                #打卡熱點#單車漫遊
# 11            饒河街觀光夜市                 #非吃不可#逛夜市
# 12               高美濕地            #打卡熱點#送夕陽#浪漫約會
# 13              田寮月世界                #地質奇觀#觀景平台
# 14    日月潭國家風景區-向山遊客中心  #無障礙#拍婚紗#單車漫遊#觀景平台#國家風景區
# 15            十分風景特定區                      #逛老街
# 16               勝興車站                #古蹟巡禮#打卡熱點
# 17              碧潭風景區       #單車漫遊#親子共遊#浪漫約會#賞夜景
# 18             新北投溫泉區                 #泡溫泉#親子共遊
# ...

# %%
data[data['Location_tag_final']=='待定義tag']

# %% [markdown]
# * tag_0->#打卡熱點
# * tag_1->#自然步道
# * tag_2->#生態體驗
# * tag_3->#古蹟巡禮
# * tag_4->#生態體驗#古蹟巡禮
# * tag_5->#國家風景區

# %%
#打卡熱點
#阿里山森林鐵路-126
#日月潭拉魯島-432
#多良車站-647
#阿里山森林鐵路車庫園區-677
tag_0=[126,432,647,677]
#自然步道
#長春祠步道-132
tag_1=[132]
#生態體驗
tag_2=[133,140,177,181,186,303,317,327,372,380,386,400,429,431,440,446,473,488,489,498,505,510,607]
#古蹟巡禮
tag_3=[182,194,214,346,357,365,590]
#生態體驗#古蹟巡禮
tag_4=[539]
#國家風景區
tag_5=[559]

# %%
loaction_list=[]
for  name in data['Location']:
    loaction_list.append(name)

# %%
loaction_list
# Out:
# ['九份',
#  '淡水',
#  '士林夜市',
#  '野柳地質公園',
#  '旗津',
#  '陽明山國家公園',
#  '烏來',
#  '西子灣',
#  '國立故宮博物院',
#  '臺北龍山寺',
#  '蓮池潭',
#  '饒河街觀光夜市',
#  '高美濕地',
#  '田寮月世界',
#  '日月潭國家風景區-向山遊客中心',
#  '十分風景特定區',
#  '勝興車站',
#  '碧潭風景區',
#  '新北投溫泉區',
#  '基隆市廟口小吃',
#  '金山',
#  '奮起湖風景區',
#  '六合觀光夜市',
#  '福隆海水浴場',
#  '東部海岸國家風景區-都歷遊客中心',
#  '愛河',
#  '墾丁國家公園',
#  '太魯閣國家公園-太魯閣遊客中心',
#  '拉拉山',
#  '淡水紅毛城',
#  '國立中正紀念堂',
#  '東北角暨宜蘭海岸國家風景區-福隆遊客中心',
#  '集集火車站',
#  '迪化街-年貨大街',
#  '澄清湖',
#  '和平島公園',
#  '埔里',
#  '安平古堡',
#  '明池森林遊樂區',
#  '鹿港老街',
#  '華西街觀光夜市',
#  '阿里山國家森林遊樂區',
#  '礁溪溫泉',
#  '平溪',
#  '台北101',
#  '龍騰斷橋',
#  '臺北忠烈祠',
#  '小琉球',
#  '總統府',
#  '三峽老街',
#  '棲蘭森林遊樂區',
#  '大鵬灣國家風景區-大鵬灣遊客中心',
#  '北關海潮公園',
#  '鶯歌',
#  '東埔溫泉',
#  '野柳海洋世界',
#  '士林官邸',
#  '石門水庫',
#  '杉林溪森林生態渡假園區',
#  '淡水漁人碼頭',
#  '壽山國家自然公園',
#  '北海岸及觀音山國家風景區-白沙灣遊客中心',
#  '西門町商圈',
#  '九族文化村',
#  '太平山國家森林遊樂區',
#  '田尾公路花園',
#  '打狗英國領事館',
#  '三義木雕博物館',
#  '東勢林場遊樂區',
#  '延平郡王祠',
#  '八里左岸',
#  '水里蛇窯',
#  '四重溪溫泉',
#  '外木山情人湖濱海大道',
#  '億載金城',
#  '關子嶺溫泉',
# ...

# %%
index_list=[]
for  name in data['Location_tag_final']:
    index_list.append(name)

# %% [markdown]
# 打卡熱點

# %%
tag='#打卡熱點'
for index_number in tag_0:
    for tag_sequence in range(len(tag_0)):
        index_list[index_number]=''
        index_list[index_number]=tag
    print(index_number)    
    print(index_list[index_number])
# Out:
# 126
# #打卡熱點
# 432
# #打卡熱點
# 647
# #打卡熱點
# 677
# #打卡熱點

# %% [markdown]
# 自然步道

# %%
tag='#自然步道'
for index_number in tag_1:
    for tag_sequence in range(len(tag_1)):
        index_list[index_number]=''
        index_list[index_number]=tag
    print(index_number)    
    print(index_list[index_number])
# Out:
# 132
# #自然步道

# %%
len(index_list)
# Out:
# 755

# %% [markdown]
# 生態體驗

# %%
tag='#生態體驗'
for index_number in tag_2:
    for tag_sequence in range(len(tag_2)):
        index_list[index_number]=''
        index_list[index_number]=tag
    print(index_number)    
    print(index_list[index_number])
# Out:
# 133
# #生態體驗
# 140
# #生態體驗
# 177
# #生態體驗
# 181
# #生態體驗
# 186
# #生態體驗
# 303
# #生態體驗
# 317
# #生態體驗
# 327
# #生態體驗
# 372
# #生態體驗
# 380
# #生態體驗
# 386
# #生態體驗
# 400
# #生態體驗
# 429
# #生態體驗
# 431
# #生態體驗
# 440
# #生態體驗
# 446
# #生態體驗
# 473
# #生態體驗
# 488
# #生態體驗
# 489
# #生態體驗
# 498
# #生態體驗
# 505
# #生態體驗
# 510
# #生態體驗
# 607
# #生態體驗

# %%
len(index_list)
# Out:
# 755

# %% [markdown]
# 古蹟巡禮

# %%
tag='#古蹟巡禮'
for index_number in tag_3:
    for tag_sequence in range(len(tag_3)):
        index_list[index_number]=''
        index_list[index_number]=tag
    print(index_number)    
    print(index_list[index_number])
# Out:
# 182
# #古蹟巡禮
# 194
# #古蹟巡禮
# 214
# #古蹟巡禮
# 346
# #古蹟巡禮
# 357
# #古蹟巡禮
# 365
# #古蹟巡禮
# 590
# #古蹟巡禮

# %% [markdown]
# 生態體驗+古蹟巡禮

# %%
tag='#生態體驗#古蹟巡禮'
for index_number in tag_4:
    for tag_sequence in range(len(tag_4)):
        index_list[index_number]=''
        index_list[index_number]=tag
    print(index_number)    
    print(index_list[index_number])
# Out:
# 539
# #生態體驗#古蹟巡禮

# %% [markdown]
# 國家風景區

# %%
tag='#國家風景區'
for index_number in tag_5:
    for tag_sequence in range(len(tag_5)):
        index_list[index_number]=''
        index_list[index_number]=tag
    print(index_number)    
    print(index_list[index_number])
# Out:
# 559
# #國家風景區

# %%
index_list
# Out:
# ['#逛老街#賞夜景#非吃不可',
#  '#逛老街#非吃不可',
#  '#打卡熱點#非吃不可#逛夜市',
#  '#地質奇觀#打卡熱點#拍婚紗#無障礙',
#  '#打卡熱點#夏天戲水#單車漫遊#逛老街',
#  '#賞花#登山步道#泡溫泉#國家風景區',
#  '#泡溫泉#逛老街',
#  '#浪漫約會#送夕陽#親子共遊#夏天戲水',
#  '#看展覽#博物館#親子共遊',
#  '#寺廟祈福#打卡熱點#古蹟巡禮',
#  '#打卡熱點#單車漫遊',
#  '#非吃不可#逛夜市',
#  '#打卡熱點#送夕陽#浪漫約會',
#  '#地質奇觀#觀景平台',
#  '#無障礙#拍婚紗#單車漫遊#觀景平台#國家風景區',
#  '#逛老街',
#  '#古蹟巡禮#打卡熱點',
#  '#單車漫遊#親子共遊#浪漫約會#賞夜景',
#  '#泡溫泉#親子共遊',
#  '#非吃不可#逛夜市',
#  '#逛老街#泡溫泉#單車漫遊',
#  '#逛老街#無障礙',
#  '#逛夜市#非吃不可#親子共遊',
#  '#夏天戲水#無障礙#迎曙光',
#  '#無障礙#單車漫遊#國家風景區',
#  '#打卡熱點#賞夜景',
#  '#地質奇觀#夏天戲水#國家風景區',
#  '#登山步道#國家風景區',
#  '#觀景平台',
#  '#古蹟巡禮',
#  '#古蹟巡禮#親子共遊#看展覽',
#  '#無障礙#單車漫遊#夏天戲水#看海景#國家風景區',
#  '#無障礙',
#  '#打卡熱點#逛老街#非吃不可',
#  '#親子共遊',
#  '#地質奇觀#親子共遊#夏天戲水#無障礙',
#  '#浪漫約會#看展覽',
#  '#打卡熱點#古蹟巡禮',
#  '#登山步道#打卡熱點',
#  '#逛老街#古蹟巡禮#非吃不可',
#  '#非吃不可#逛夜市',
#  '#賞花#迎曙光#登山步道#無障礙',
#  '#泡溫泉',
#  '#逛老街',
#  '#觀景平台#打卡熱點',
#  '#打卡熱點#古蹟巡禮',
#  '#打卡熱點',
#  '#打卡熱點#夏天戲水#單車漫遊#地質奇觀',
#  '#打卡熱點',
#  '#逛老街',
#  '#登山步道#賞花',
#  '#夏天戲水#單車漫遊#無障礙#國家風景區',
#  '#地質奇觀#觀景平台',
# ...

# %%
info={}
info['Location']=loaction_list
info['Location_tag_final']=index_list

# %%
result=pd.DataFrame.from_dict(info)

# %%
result
# Out:
#              Location        Location_tag_final
# 0                  九份             #逛老街#賞夜景#非吃不可
# 1                  淡水                 #逛老街#非吃不可
# 2                士林夜市            #打卡熱點#非吃不可#逛夜市
# 3              野柳地質公園        #地質奇觀#打卡熱點#拍婚紗#無障礙
# 4                  旗津       #打卡熱點#夏天戲水#單車漫遊#逛老街
# 5             陽明山國家公園        #賞花#登山步道#泡溫泉#國家風景區
# 6                  烏來                  #泡溫泉#逛老街
# 7                 西子灣       #浪漫約會#送夕陽#親子共遊#夏天戲水
# 8             國立故宮博物院             #看展覽#博物館#親子共遊
# 9               臺北龍山寺           #寺廟祈福#打卡熱點#古蹟巡禮
# 10                蓮池潭                #打卡熱點#單車漫遊
# 11            饒河街觀光夜市                 #非吃不可#逛夜市
# 12               高美濕地            #打卡熱點#送夕陽#浪漫約會
# 13              田寮月世界                #地質奇觀#觀景平台
# 14    日月潭國家風景區-向山遊客中心  #無障礙#拍婚紗#單車漫遊#觀景平台#國家風景區
# 15            十分風景特定區                      #逛老街
# 16               勝興車站                #古蹟巡禮#打卡熱點
# 17              碧潭風景區       #單車漫遊#親子共遊#浪漫約會#賞夜景
# 18             新北投溫泉區                 #泡溫泉#親子共遊
# ...

# %%
result.to_csv('tag_process_完成_05-19.csv',index=False)
