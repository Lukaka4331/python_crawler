# %%
import requests
import time
from bs4 import BeautifulSoup
from selenium import webdriver
from selenium.webdriver.common.keys import Keys

# %%
ETtoday_url = "https://www.ettoday.net/news/focus/%E8%B2%A1%E7%B6%93/"  #財經新聞

# %%
ddriver = webdriver.Chrome()
ddriver.get(ETtoday_url)

# %%
SCROLL_PAUSE_TIME = 1

#
# 以下是用Selenium模擬下拉網頁動作，讓網頁更新
#
last_height = ddriver.execute_script("window.scrollTo(0, document.body.scrollHeight);")
while True:
    '''
    Your code here
    
    提示：可參考以下的Stack Overflow: 
    https://stackoverflow.com/questions/48850974/selenium-scroll-to-end-of-page-indynamically-loading-webpage/48851166
    '''

    # Scroll down to the bottom.
    ddriver.execute_script("window.scrollTo(0, document.body.scrollHeight);")

    # Wait to load the page.
    time.sleep(1)

    # Calculate new scroll height and compare with last scroll height.
    new_height = ddriver.execute_script("return document.body.scrollHeight")

    if new_height == last_height:
        print("到達頁面底端")
        break

    last_height = new_height
    print("網頁更新中...")
# Out:
# 網頁更新中...
# 網頁更新中...
# 網頁更新中...
# 網頁更新中...
# 網頁更新中...
# 網頁更新中...
# 網頁更新中...
# 網頁更新中...
# 網頁更新中...
# 到達頁面底端

# %%
# 這裡先建立一個函數，其功能是連到外部連結，並爬取新聞內容。
#
def getNewsDetailContent(link_url):
    resp = requests.get(link_url)
    resp.encoding = 'utf-8'
    #print(resp.text)

    soup = BeautifulSoup(resp.text, 'lxml')
    news_content = soup.find("div", attrs={'class':'story'}).find_all("p")
    for p in news_content:
        """
        .string屬性說明：
        (1) 若當前tag節點底下沒有其他tag子節點，會直接抓取內容(返回"NavigableString")
        (2) 若當前tag節點底下只有唯一的一個tag子節點，也會直接抓取tag子節點的內容(返回"NavigableString")
        (3) 但若當前tag節點底下還有很多個tag子節點，.string就無法判斷，(返回"None")
        """
        if ((p.string) is not None):
            print(p.string)

# %%
# 爬取網頁內容，解析後萃取新聞摘要
html = ddriver.page_source
soup = BeautifulSoup(html, "lxml")
all_news = soup.find("div", attrs={'class':'block block_1 infinite_scroll'})

news_block = all_news.find_all('div', attrs={'class':'piece clearfix'})

for i, news_item in enumerate(news_block):
    print("----------------------------------------------------------------------")
    news_body = news_item.find('h3')
    print("\n[%d] %s\n" % (i, news_body.a.string))
    
    # 
    # 連到外部連結，擷取詳細新聞內容
    #
    externalLink = "https://www.ettoday.net" + news_item.a["href"]
    getNewsDetailContent(externalLink)
# Out:
# ----------------------------------------------------------------------
#
# [0] 台灣恐被列匯率操縱國觀察名單　央行總裁楊金龍：相關單位會安排因應
#
# ▲ 中央銀行總裁楊金龍。（資料照／記者湯興漢攝）
# 記者李瑞瑾／台北報導
# 美國財政部定期發布匯率操縱國名單，央行總裁楊金龍表示，台灣去年全年已達三項標準中的二項，4月可能會被列入觀察名單當中，針對立委質詢台灣被列匯率操縱國觀察該怎麼辦，楊金龍表示，「相關單位都知道這些問題，也有在安排如何因應」。
# 美國財政部判定貿易夥伴是否操縱匯率的3項指標分別為：鉅額對美貿易順差（超過200億美元）、鉅額經常帳順差（佔GDP的3%以上）、持續的單邊外匯市場干預（該經濟體透過買入外國資產促使本國貨幣貶值，且年度內購買總金額超過GDP 2%）。若一個國家或地區符合上述三項指標，即會被認定為匯率操縱國；若滿足其中二項或在美國的總體貿易逆差過大，則會被列入匯率操縱觀察名單。
# 事實上，楊金龍也曾於去年第四季的理監事會後記者會中提到，這份匯率報告詳細檢討都是跟貿易有關，跟匯率沒有什麼關係，三項指標中也只有第三個標準跟匯率相關；但他也表示，「雖然不是中央銀行問題，是貿易問題，我們還是可以跟他討論。」，央行每年都會跟美國財政部談，以往跟他們的溝通也很良好。
# ----------------------------------------------------------------------
#
# [1] 亞股受驚！日港股暴跌近千點、韓台股跌幅逾4％　陸股下跌逾1％已是相對抗跌
#
# ▲亞洲主要股市，目前全面下挫中。（資料照／路透）
# 記者李錦奇／綜合報導
# 美股暴跌，加上美股期貨指數目前大跌4％，驚嚇到亞洲主要股市，目前全面下挫中，其中，日韓股市以及台股，跌勢最重，跌幅都超過4％。
# 截至今天上午11點25分為止，南韓股市大跌4.24％，跌至1827點。
# 日經指數大跌1003點，跌幅高達5.17％。
# 港股恆生指數大跌920點，跌幅3.65％。
# 相較之下，陸股上証指數下跌1.3％，跌至2928點，表現已經是相對抗跌。
# ...
