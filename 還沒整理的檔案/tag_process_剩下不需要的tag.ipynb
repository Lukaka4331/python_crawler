# %%
import requests
from bs4 import BeautifulSoup
import time
import pandas as pd
import re
from tqdm.notebook import tqdm

# %%
ss=pd.read_csv('C:/Users/csie/Desktop/python_2020-04-30/tag_no_process.csv')

# %%
ss.tail()
# Out:
#            hash_tag
# 750   #無障礙#漫遊客庄#看展覽
# 751       #無障礙#漫遊客庄
# 752  #無障礙#登山步道#生態體驗
# 753       #無障礙#單車漫遊
# 754  #無障礙#漫遊客庄#寺廟祈福

# %%
#page_all_final=pd.read_csv('F:/下載的地方/python_crawler-master/python_crawler-master/page_all_final.csv')
#index_list=[]
#for  name in page_all_final['Url']:
#    index_list.append(name)

# %%
#data={}
#data['hash_tag']=[]
#a=['#古蹟巡禮']

# %%
#for t_hash_tag in tqdm(range(len(index_list)),desc='hash_tag'):
#    resp = requests.get(index_list[t_hash_tag])
#    soup = BeautifulSoup(resp.text, 'lxml')
#    hash_tag=[tag.text for tag in soup.find("div",{"class":"infoside"}).find_all("div",{"class":"hashtag"})]
#    if hash_tag :
#        data['hash_tag'].extend(hash_tag)
#        #print(t_hash_tag)
#    else:
#        print ("empty")#247-empty
#        print(t_hash_tag)
#        data['hash_tag'].extend(a)#tag訂為:古蹟巡禮

# %% [markdown]
# # 替換字元

# %%
list_text = ['#網美必拍#夏天戲水#單車漫遊#逛老街', '#泡溫泉#生態體驗#逛老街', '#逛老街#泡溫泉#單車漫遊']

NEW_S = list(map(lambda list_text: list_text.replace('#網美必拍','#打卡熱點'), list_text))
print(NEW_S)

# %%
s = '我是李大中，英文名字叫做John'
pos = s.rfind('李大中')
print('李大中的位置：' + str(pos))
# Out:
# 李大中的位置：2

# %%
ss['hash_tag']
# Out:
# 0                  #逛老街#賞夜景#非吃不可
# 1                      #逛老街#非吃不可
# 2                 #打卡熱點#非吃不可#逛夜市
# 3             #地質奇觀#打卡熱點#拍婚紗#無障礙
# 4            #網美必拍#夏天戲水#單車漫遊#逛老街
# 5         #賞花#生態體驗#登山步道#泡溫泉#國家公園
# 6                  #泡溫泉#生態體驗#逛老街
# 7            #浪漫約會#送夕陽#親子共遊#夏天戲水
# 8                  #看展覽#博物館#親子共遊
# 9                #寺廟祈福#打卡熱點#古蹟巡禮
# 10                    #打卡熱點#單車漫遊
# 11                     #非吃不可#逛夜市
# 12           #生態體驗#打卡熱點#送夕陽#浪漫約會
# 13                    #地質奇觀#觀景平台
# 14      #無障礙#拍婚紗#單車漫遊#觀景平台#國家風景區
# 15                     #逛老街#鐵道旅遊
# 16               #古蹟巡禮#鐵道旅遊#打卡熱點
# 17           #單車漫遊#親子共遊#浪漫約會#賞夜景
# 18                     #泡溫泉#親子共遊
# 19                     #非吃不可#逛夜市
# 20                 #逛老街#泡溫泉#單車漫遊
# 21                #逛夜市#非吃不可#親子共遊
# 22                 #生態體驗#逛老街#無障礙
# 23            #水上活動#夏天戲水#無障礙#迎曙光
# 24     #部落旅遊#生態體驗#無障礙#單車漫遊#國家風景區
# 25                     #打卡熱點#賞夜景
# 26          #生態體驗#地質奇觀#夏天戲水#國家公園
# 27               #生態體驗#登山步道#國家公園
# 28                    #生態體驗#觀景平台
# 29                    #古蹟巡禮#戰地文化
#                  ...
# 725                    #無障礙#親子共遊
# 726                         #無障礙
# 727                    #無障礙#部落旅遊
# 728                         #無障礙
# 729                    #無障礙#部落旅遊
# 730                    #無障礙#戰地文化
# 731                    #無障礙#戰地文化
# 732                    #無障礙#部落旅遊
# 733                     #網美必拍#燈塔
# 734                        #親子共遊
# 735                        #親子共遊
# 736                         #博物館
# 737                         #逛老街
# 738                        #親子共遊
# 739                    #博物館#親子共遊
# 740                        #古蹟巡禮
# 741                         #博物館
# 742                    #無障礙#網美必拍
# 743           #無障礙#漫遊客庄#看展覽#親子共遊
# 744                    #無障礙#親子共遊
# 745               #無障礙#生態體驗#打卡熱點
# 746                    #無障礙#漫遊客庄
# 747                #無障礙#看展覽#漫遊客庄
# 748                    #無障礙#生態體驗
# 749                 #無障礙#看展覽#博物館
# 750                #無障礙#漫遊客庄#看展覽
# 751                    #無障礙#漫遊客庄
# 752               #無障礙#登山步道#生態體驗
# 753                    #無障礙#單車漫遊
# 754               #無障礙#漫遊客庄#寺廟祈福
# Name: hash_tag, Length: 755, dtype: object

# %%
#ss=pd.read_csv('C:/Users/b/Desktop/python_2020-05-05/tag_no_process.csv')
data_tag=[]
for  name in ss['hash_tag']:
    data_tag.append(name)

# %%
len(data_tag)
# Out:
# 755

# %%
data_tag[4]
# Out:
# '#網美必拍#夏天戲水#單車漫遊#逛老街'

# %%
op='#網美必拍'
sd=re.findall(op,data_tag[4])
print(sd)
# Out:
# ['#網美必拍']

# %%
data_2020_ok=[data_tag[117]]
#if '#網美必拍' or '' in data_tag[4]:

if  '#網美必拍' in data_2020_ok[0] or '#文青必訪' in data_2020_ok[0]:
    print('have')
    #data_2020_ok.replace(('#網美必拍','#打卡熱點'), data_2020_ok)
    data_process_1 = list(map(lambda data_2020_ok: data_2020_ok.replace('#網美必拍','#打卡熱點'), data_2020_ok))        
    print(data_2020_ok)
    print(data_process_1)
    
else :
    print('not have')
    print(data_2020_ok)
# Out:
# not have
# ['#逛老街#非吃不可']

# %%
data_2020_ok=[data_tag[4]]
print(data_2020_ok)
print('#網美必拍' in data_2020_ok[0])
x = "hello world"
print('hello' in x)
# Out:
# ['#網美必拍#夏天戲水#單車漫遊#逛老街']
# True
# True

# %%
data_2020_ok=[data_tag[117]]
if '#網美必拍' in  data_2020_ok[0] or '#文青必訪' in  data_2020_ok[0]:
    print(data_2020_ok)
else :
    print(data_2020_ok)
# Out:
# ['#逛老街#非吃不可']

# %%
data_try={}
data_try['try_tag']=[]
data_2020_ok=[data_tag[4]]
#if '#網美必拍' or '' in data_tag[4]:
if '#網美必拍' in  data_2020_ok[0] or '#文青必訪' in  data_2020_ok[0]:
    print('have')
    #data_2020_ok.replace(('#網美必拍','#打卡熱點'), data_2020_ok)
    data_process_1 = list(map(lambda data_2020_ok: data_2020_ok.replace('#網美必拍','#打卡熱點'), data_2020_ok))        
    #print(data_2020_ok)
    #print(data_process_1)
    data_try['try_tag'].extend(data_process_1)
    print(data_try['try_tag'])
    
else :
    print('not have')
    print(data_2020_ok)
# Out:
# have
# ['#打卡熱點#夏天戲水#單車漫遊#逛老街']

# %%
see=['']

# %%
for i in tqdm(range(len(data_tag))):
    data_2020_ok=[data_tag[i]]
    if '#台灣燈會' in  data_2020_ok[0] or '#生態體驗' in  data_2020_ok[0] or '#部落旅遊' in  data_2020_ok[0] or '#戰地文化' in  data_2020_ok[0] or '#鐵道旅遊' in  data_2020_ok[0]:
        #print(i)
        data_process_1 = list(map(lambda data_2020_ok: data_2020_ok.replace('#台灣燈會',''), data_2020_ok)) 
        print(data_process_1)
        if  see in data_process_1 :
            print(i)
            print('shave!') 
            #see.extend(a)
            #print(see)
            #print(data_process_1)
        else :
            #see.extend(a)
            print(i)
            print('not have')
    else :
        print(i)
        print('other')
# Out:
# HBox(children=(FloatProgress(value=0.0, max=755.0), HTML(value='')))
# 0
# other
# 1
# other
# 2
# other
# 3
# other
# 4
# other
# ['#賞花#生態體驗#登山步道#泡溫泉#國家公園']
# 5
# not have
# ['#泡溫泉#生態體驗#逛老街']
# 6
# not have
# 7
# other
# 8
# other
# 9
# other
# 10
# other
# 11
# other
# ['#生態體驗#打卡熱點#送夕陽#浪漫約會']
# 12
# not have
# 13
# other
# 14
# other
# ['#逛老街#鐵道旅遊']
# 15
# not have
# ['#古蹟巡禮#鐵道旅遊#打卡熱點']
# 16
# not have
# 17
# other
# 18
# other
# 19
# other
# 20
# other
# 21
# other
# ['#生態體驗#逛老街#無障礙']
# 22
# not have
# 23
# other
# ['#部落旅遊#生態體驗#無障礙#單車漫遊#國家風景區']
# 24
# not have
# 25
# other
# ['#生態體驗#地質奇觀#夏天戲水#國家公園']
# 26
# not have
# ['#生態體驗#登山步道#國家公園']
# 27
# not have
# ['#生態體驗#觀景平台']
# 28
# not have
# ['#古蹟巡禮#戰地文化']
# 29
# not have
# ['#古蹟巡禮#親子共遊#看展覽#生態體驗']
# 30
# not have
# 31
# other
# 32
# other
# 33
# other
# ['#親子共遊#生態體驗']
# 34
# not have
# 35
# other
# ['#浪漫約會#生態體驗#藝術']
# 36
# not have
# 37
# other
# ['#森林步道#生態體驗#打卡熱點']
# 38
# not have
# 39
# other
# 40
# other
# 41
# other
# 42
# other
# ['#逛老街#鐵道旅遊']
# 43
# not have
# 44
# other
# 45
# other
# 46
# other
# 47
# other
# 48
# other
# 49
# other
# 50
# other
# ['#生態體驗#夏天戲水#單車漫遊#無障礙#國家風景區']
# 51
# not have
# 52
# other
# 53
# other
# ['#泡溫泉#部落旅遊']
# 54
# not have
# 55
# other
# 56
# other
# ['#生態體驗#賞花#單車漫遊#登山步道']
# 57
# not have
# ['#生態體驗#賞花#打卡熱點#登山步道']
# 58
# not have
# 59
# other
# ['#登山步道#生態體驗#國家公園']
# 60
# not have
# ['#地質奇觀#生態體驗#夏天戲水#拍婚紗#國家風景區']
# 61
# not have
# ['#打卡熱點#賞花#部落旅遊']
# 62
# not have
# 63
# other
# ['#森林步道#泡溫泉#生態體驗']
# 64
# not have
# 65
# other
# 66
# other
# 67
# other
# ['#生態體驗#森林步道#賞花']
# 68
# not have
# 69
# other
# 70
# other
# 71
# other
# 72
# other
# 73
# other
# ['#戰地文化#古蹟巡禮']
# 74
# not have
# 75
# other
# 76
# other
# ['#無障礙#生態體驗#單車漫遊#親子共遊']
# 77
# not have
# 78
# other
# ['#賞花#親子共遊#生態體驗']
# 79
# not have
# 80
# other
# ['#生態體驗#觀景平台#登山步道']
# 81
# not have
# 82
# other
# 83
# other
# 84
# other
# 85
# other
# 86
# other
# ['#生態體驗#登山步道#觀景平台']
# 87
# not have
# 88
# other
# ['#森林步道#生態體驗#迎曙光#賞花']
# 89
# not have
# 90
# other
# 91
# other
# 92
# other
# 93
# other
# 94
# other
# ['#無障礙#部落旅遊']
# 95
# not have
# 96
# other
# 97
# other
# 98
# other
# 99
# other
# ['#生態體驗#賞花#單車漫遊#國家風景區']
# 100
# not have
# 101
# other
# 102
# other
# ['#生態體驗#森林步道#觀景平台#親子共遊']
# 103
# not have
# ['#打卡熱點#水上活動#泡溫泉#生態體驗']
# 104
# not have
# ['#部落旅遊#無障礙#生態體驗#浪漫約會#國家風景區']
# 105
# not have
# 106
# other
# 107
# other
# 108
# other
# ['#生態體驗#親子共遊']
# 109
# not have
# ['#生態體驗#親子共遊']
# 110
# not have
# 111
# other
# 112
# other
# 113
# other
# 114
# other
# 115
# other
# 116
# other
# 117
# other
# 118
# other
# 119
# other
# 120
# other
# ['#生態體驗#賞花#浪漫約會#親子共遊']
# 121
# not have
# ['#地質奇觀#登山步道#生態體驗']
# 122
# not have
# 123
# other
# ['#逛老街#鐵道旅遊#賞花#漫遊客庄']
# 124
# not have
# ['#生態體驗#親子共遊']
# 125
# not have
# ['#生態體驗#鐵道旅遊']
# 126
# not have
# 127
# other
# 128
# other
# 129
# other
# 130
# other
# ['#生態體驗']
# 131
# not have
# ['#古蹟巡禮#戰地文化']
# 132
# not have
# ['#生態體驗']
# 133
# not have
# 134
# other
# ['#生態體驗#登山步道#迎曙光#賞花']
# 135
# not have
# 136
# other
# 137
# other
# ['#生態體驗#親子共遊#博物館']
# 138
# not have
# ['#單車漫遊#鐵道旅遊#逛老街#登山步道']
# 139
# not have
# ['#生態體驗']
# 140
# not have
# 141
# other
# 142
# other
# ['#生態體驗#藝術#網美必拍']
# 143
# not have
# 144
# other
# 145
# other
# 146
# other
# 147
# other
# 148
# other
# 149
# other
# ['#部落旅遊#無障礙']
# 150
# not have
# 151
# other
# 152
# other
# 153
# other
# 154
# other
# 155
# other
# ['#賞花#生態體驗#觀景平台']
# 156
# not have
# 157
# other
# 158
# other
# 159
# other
# 160
# other
# 161
# other
# 162
# other
# 163
# other
# ['#登山步道#地質奇觀#生態體驗#賞花']
# 164
# not have
# ['#部落旅遊#賞花']
# 165
# not have
# 166
# other
# 167
# other
# 168
# other
# 169
# other
# ['#生態體驗#登山步道#觀景平台#泡溫泉']
# 170
# not have
# ['#打卡熱點#古蹟巡禮#戰地文化']
# 171
# not have
# 172
# other
# 173
# other
# 174
# other
# 175
# other
# 176
# other
# ['#生態體驗#部落旅遊']
# 177
# not have
# ['#無障礙#古蹟巡禮#戰地文化']
# 178
# not have
# ['#親子共遊#生態體驗#夏天戲水']
# 179
# not have
# ['#登山步道#生態體驗']
# 180
# not have
# ['#生態體驗#部落旅遊']
# 181
# not have
# ['#戰地文化']
# 182
# not have
# ['#打卡熱點#古蹟巡禮#戰地文化']
# 183
# not have
# ['#部落旅遊#打卡熱點#地質奇觀#生態體驗']
# 184
# not have
# ['#無障礙#打卡熱點#單車漫遊#生態體驗']
# 185
# not have
# ['#部落旅遊#生態體驗']
# 186
# not have
# 187
# other
# 188
# other
# ['#生態體驗#親子共遊']
# 189
# not have
# 190
# other
# ['#生態體驗#登山步道']
# 191
# not have
# ['#古蹟巡禮#戰地文化']
# 192
# not have
# ['#森林步道#親子共遊#生態體驗']
# 193
# not have
# ['#生態體驗']
# 194
# not have
# 195
# other
# 196
# other
# ['#單車漫遊#生態體驗#水上活動']
# 197
# not have
# 198
# other
# ['#登山步道#生態體驗#觀景平台#賞花']
# 199
# not have
# 200
# other
# ['#親子共遊#夏天戲水#觀景平台#戰地文化']
# 201
# not have
# 202
# other
# 203
# other
# ['#生態體驗#森林步道']
# 204
# not have
# 205
# other
# 206
# other
# ['#生態體驗#賞花']
# 207
# not have
# 208
# other
# 209
# other
# 210
# other
# 211
# other
# ['#親子共遊#生態體驗']
# 212
# not have
# ['#部落旅遊#泡溫泉#生態體驗#無障礙']
# 213
# not have
# ['#戰地文化']
# 214
# not have
# ['#地質奇觀#生態體驗']
# 215
# not have
# 216
# other
# 217
# other
# ['#生態體驗#親子共遊']
# 218
# not have
# 219
# other
# 220
# other
# ['#森林步道#生態體驗']
# 221
# not have
# 222
# other
# 223
# other
# 224
# other
# ['#親子共遊#生態體驗']
# 225
# not have
# ['#生態體驗#親子共遊']
# 226
# not have
# ['#無障礙#親子共遊#生態體驗#單車漫遊']
# 227
# not have
# 228
# other
# 229
# other
# 230
# other
# 231
# other
# 232
# other
# 233
# other
# 234
# other
# 235
# other
# ['#森林步道#泡溫泉#生態體驗']
# 236
# not have
# 237
# other
# 238
# other
# 239
# other
# 240
# other
# ['#親子共遊#生態體驗']
# 241
# not have
# ['#生態體驗#賞花#森林步道']
# 242
# not have
# 243
# other
# 244
# other
# 245
# other
# ['#泡溫泉#生態體驗#森林步道']
# 246
# not have
# 247
# other
# 248
# other
# ['#地質奇觀#觀景平台#生態體驗#送夕陽']
# 249
# not have
# ['#生態體驗#登山步道#賞花#迎曙光']
# 250
# not have
# 251
# other
# 252
# other
# ['#單車漫遊#賞花#生態體驗']
# 253
# not have
# 254
# other
# ['#森林步道#生態體驗']
# 255
# not have
# 256
# other
# 257
# other
# 258
# other
# ['#生態體驗#送夕陽']
# 259
# not have
# 260
# other
# 261
# other
# 262
# other
# ['#生態體驗#登山步道#賞花#無障礙']
# 263
# not have
# 264
# other
# 265
# other
# 266
# other
# 267
# other
# ['#生態體驗#賞花#親子共遊#網美必拍']
# 268
# not have
# ['#送夕陽#網美必拍#生態體驗']
# 269
# not have
# 270
# other
# 271
# other
# ['#古蹟巡禮#戰地文化#生態體驗#國家公園']
# 272
# not have
# 273
# other
# ['#生態體驗#無障礙#國家公園']
# 274
# not have
# ['#鐵道旅遊#單車漫遊#古蹟巡禮']
# 275
# not have
# ['#登山步道#生態體驗#國家公園']
# 276
# not have
# 277
# other
# 278
# other
# 279
# other
# 280
# other
# 281
# other
# 282
# other
# 283
# other
# 284
# other
# 285
# other
# 286
# other
# 287
# other
# 288
# other
# 289
# other
# ['#生態體驗#親子共遊#單車漫遊']
# 290
# not have
# ['#生態體驗#親子共遊#賞花']
# 291
# not have
# 292
# other
# 293
# other
# 294
# other
# 295
# other
# ['#生態體驗#登山步道#夏天戲水#親子共遊']
# 296
# not have
# 297
# other
# 298
# other
# 299
# other
# ['#生態體驗#單車漫遊']
# 300
# not have
# 301
# other
# 302
# other
# ['#生態體驗#部落旅遊']
# 303
# not have
# 304
# other
# 305
# other
# 306
# other
# 307
# other
# 308
# other
# ['#生態體驗#親子共遊#夏天戲水#單車漫遊']
# 309
# not have
# 310
# other
# 311
# other
# 312
# other
# 313
# other
# ['#登山步道#生態體驗#觀景平台']
# 314
# not have
# ['#泡溫泉#生態體驗#森林步道']
# 315
# not have
# ['#生態體驗#登山步道#國家公園#無障礙']
# 316
# not have
# ['#生態體驗']
# 317
# not have
# 318
# other
# 319
# other
# 320
# other
# ['#地質奇觀#生態體驗#登山步道']
# 321
# not have
# ['#地質奇觀#生態體驗']
# 322
# not have
# 323
# other
# 324
# other
# ['#生態體驗#親子共遊']
# 325
# not have
# 326
# other
# ['#生態體驗']
# 327
# not have
# ['#拍婚紗#生態體驗#親子共遊#網美必拍#國家風景區']
# 328
# not have
# ['#觀景平台#地質奇觀#部落旅遊']
# 329
# not have
# 330
# other
# 331
# other
# 332
# other
# 333
# other
# 334
# other
# 335
# other
# ['#生態體驗#登山步道#賞花#國家風景區']
# 336
# not have
# 337
# other
# 338
# other
# 339
# other
# 340
# other
# ['#無障礙#戰地文化']
# 341
# not have
# 342
# other
# 343
# other
# 344
# other
# 345
# other
# ['#生態體驗']
# 346
# not have
# 347
# other
# ['#登山步道#生態體驗']
# 348
# not have
# 349
# other
# 350
# other
# 351
# other
# ['#生態體驗#親子共遊']
# 352
# not have
# ['#生態體驗#親子共遊']
# 353
# not have
# ['#觀景平台#生態體驗']
# 354
# not have
# 355
# other
# 356
# other
# ['#戰地文化']
# 357
# not have
# 358
# other
# 359
# other
# ['#生態體驗#無障礙#賞花#漫遊客庄']
# 360
# not have
# 361
# other
# 362
# other
# 363
# other
# ['#戰地文化']
# 364
# not have
# ['#生態體驗#泡溫泉#部落旅遊']
# 365
# not have
# ['#單車漫遊#生態體驗']
# 366
# not have
# 367
# other
# 368
# other
# 369
# other
# ['#生態體驗#古蹟巡禮']
# 370
# not have
# ['#無障礙#生態體驗']
# 371
# not have
# ['#生態體驗']
# 372
# not have
# ['#無障礙#生態體驗#親子共遊']
# 373
# not have
# 374
# other
# 375
# other
# ['#親子共遊#生態體驗#賞花']
# 376
# not have
# 377
# other
# 378
# other
# ['#生態體驗']
# 379
# not have
# ['#生態體驗#夏天戲水']
# 380
# not have
# 381
# other
# 382
# other
# 383
# other
# 384
# other
# 385
# other
# 386
# other
# ['#生態體驗']
# 387
# not have
# 388
# other
# 389
# other
# ['#賞夜景#浪漫約會#登山步道#生態體驗']
# 390
# not have
# 391
# other
# ['#地質奇觀#生態體驗#觀景平台']
# 392
# not have
# ['#泡溫泉#登山步道#生態體驗']
# 393
# not have
# 394
# other
# 395
# other
# 396
# other
# 397
# other
# ['#海灣旅遊#無障礙#夏天戲水#生態體驗#國家風景區']
# 398
# not have
# ['#生態體驗#登山步道']
# 399
# not have
# ['#部落旅遊']
# 400
# not have
# ['#登山步道#生態體驗']
# 401
# not have
# ['#登山步道#生態體驗']
# 402
# not have
# 403
# other
# 404
# other
# 405
# other
# 406
# other
# ['#部落旅遊#生態體驗#夏天戲水']
# 407
# not have
# ['#賞夜景#浪漫約會#登山步道#生態體驗']
# 408
# not have
# 409
# other
# ['#親子共遊#生態體驗']
# 410
# not have
# ['#無障礙#部落旅遊']
# 411
# not have
# 412
# other
# 413
# other
# 414
# other
# 415
# other
# 416
# other
# ['#部落旅遊#生態體驗#水上活動#單車漫遊']
# 417
# not have
# 418
# other
# 419
# other
# 420
# other
# 421
# other
# 422
# other
# 423
# other
# 424
# other
# ['#生態體驗#登山步道#親子共遊']
# 425
# not have
# 426
# other
# ['#生態體驗#戰地文化#國家風景區']
# 427
# not have
# ['#親子共遊#生態體驗#打卡熱點']
# 428
# not have
# ['#部落旅遊']
# 429
# not have
# 430
# other
# ['#生態體驗#登山步道']
# 431
# not have
# ['#部落旅遊']
# 432
# not have
# ['#生態體驗']
# 433
# not have
# ['#古蹟巡禮#戰地文化']
# 434
# not have
# ['#生態體驗#親子共遊']
# 435
# not have
# 436
# other
# 437
# other
# 438
# other
# ['#地質奇觀#生態體驗#觀景平台']
# 439
# not have
# ['#生態體驗']
# 440
# not have
# ['#生態體驗#登山步道']
# 441
# not have
# 442
# other
# 443
# other
# ['#生態體驗#登山步道#賞花#漫遊客庄']
# 444
# not have
# ['#生態體驗#親子共遊']
# 445
# not have
# ['#生態體驗']
# 446
# not have
# ['#打卡熱點#生態體驗']
# 447
# not have
# 448
# other
# ['#地質奇觀#生態體驗#泡溫泉']
# 449
# not have
# 450
# other
# 451
# other
# 452
# other
# ['#生態體驗#觀景平台#登山步道']
# 453
# not have
# 454
# other
# ['#生態體驗#泡溫泉#親子共遊#部落旅遊']
# 455
# not have
# ['#生態體驗#無障礙']
# 456
# not have
# ['#親子共遊#生態體驗']
# 457
# not have
# ['#地質奇觀#生態體驗']
# 458
# not have
# 459
# other
# ['#生態體驗#賞花#單車漫遊']
# 460
# not have
# 461
# other
# 462
# other
# ['#水上活動#生態體驗#親子共遊']
# 463
# not have
# 464
# other
# ['#生態體驗#登山步道#賞花']
# 465
# not have
# ['#單車漫遊#生態體驗']
# 466
# not have
# 467
# other
# ['#無障礙#親子共遊#生態體驗']
# 468
# not have
# 469
# other
# 470
# other
# 471
# other
# 472
# other
# ['#生態體驗']
# 473
# not have
# 474
# other
# ['#生態體驗#森林步道#親子共遊']
# 475
# not have
# 476
# other
# 477
# other
# 478
# other
# ['#地質奇觀#生態體驗']
# 479
# not have
# 480
# other
# 481
# other
# 482
# other
# 483
# other
# 484
# other
# 485
# other
# 486
# other
# 487
# other
# ['#生態體驗']
# 488
# not have
# ['#部落旅遊']
# 489
# not have
# 490
# other
# 491
# other
# 492
# other
# 493
# other
# 494
# other
# ['#無障礙#登山步道#戰地文化']
# 495
# not have
# ['#古蹟巡禮#戰地文化']
# 496
# not have
# 497
# other
# ['#生態體驗']
# 498
# not have
# ['#生態體驗#親子共遊#森林步道']
# 499
# not have
# 500
# other
# 501
# other
# 502
# other
# 503
# other
# 504
# other
# ['#生態體驗']
# 505
# not have
# 506
# other
# 507
# other
# 508
# other
# ['#單車漫遊#生態體驗']
# 509
# not have
# ['#生態體驗']
# 510
# not have
# ['#登山步道#親子共遊#生態體驗']
# 511
# not have
# 512
# other
# 513
# other
# 514
# other
# ['#寺廟祈福#登山步道#生態體驗#單車漫遊']
# 515
# not have
# ['#登山步道#生態體驗']
# 516
# not have
# 517
# other
# 518
# other
# ['#文青必訪#親子共遊#生態體驗#看展覽#打卡熱點']
# 519
# not have
# 520
# other
# 521
# other
# 522
# other
# 523
# other
# 524
# other
# 525
# other
# 526
# other
# 527
# other
# 528
# other
# 529
# other
# ['#森林步道#生態體驗']
# 530
# not have
# 531
# other
# 532
# other
# 533
# other
# 534
# other
# 535
# other
# 536
# other
# 537
# other
# 538
# other
# 539
# other
# ['#生態體驗#戰地文化']
# 540
# not have
# 541
# other
# 542
# other
# 543
# other
# 544
# other
# 545
# other
# 546
# other
# 547
# other
# 548
# other
# 549
# other
# 550
# other
# 551
# other
# ['#生態體驗#親子共遊#登山步道']
# 552
# not have
# 553
# other
# 554
# other
# 555
# other
# 556
# other
# 557
# other
# ['#生態體驗']
# 558
# not have
# 559
# other
# ['#藝術#生態體驗#賞花']
# 560
# not have
# 561
# other
# 562
# other
# 563
# other
# 564
# other
# 565
# other
# 566
# other
# 567
# other
# 568
# other
# 569
# other
# 570
# other
# 571
# other
# 572
# other
# 573
# other
# ['#夏天戲水#水上活動#生態體驗#親子共遊']
# 574
# not have
# 575
# other
# 576
# other
# 577
# other
# 578
# other
# 579
# other
# 580
# other
# ['#地質奇觀#生態體驗#夏天戲水#拍婚紗']
# 581
# not have
# 582
# other
# 583
# other
# 584
# other
# ['#生態體驗#親子共遊']
# 585
# not have
# ['#博物館#生態體驗#親子共遊']
# 586
# not have
# 587
# other
# 588
# other
# 589
# other
# ['#部落旅遊']
# 590
# not have
# 591
# other
# 592
# other
# 593
# other
# 594
# other
# 595
# other
# 596
# other
# 597
# other
# 598
# other
# 599
# other
# 600
# other
# 601
# other
# 602
# other
# ['#生態體驗#打卡熱點']
# 603
# not have
# 604
# other
# 605
# other
# ['#無障礙#網美必拍#單車漫遊#生態體驗']
# 606
# not have
# ['#生態體驗']
# 607
# not have
# 608
# other
# 609
# other
# 610
# other
# 611
# other
# 612
# other
# ['#生態體驗#登山步道']
# 613
# not have
# 614
# other
# 615
# other
# 616
# other
# 617
# other
# 618
# other
# 619
# other
# 620
# other
# ['#打卡熱點#生態體驗']
# 621
# not have
# 622
# other
# 623
# other
# ['#無障礙#生態體驗#親子共遊#單車漫遊']
# 624
# not have
# 625
# other
# 626
# other
# 627
# other
# 628
# other
# 629
# other
# 630
# other
# 631
# other
# 632
# other
# 633
# other
# 634
# other
# 635
# other
# 636
# other
# 637
# other
# ['#無障礙#生態體驗#觀景平台']
# 638
# not have
# 639
# other
# 640
# other
# 641
# other
# 642
# other
# 643
# other
# 644
# other
# 645
# other
# ['#無障礙#生態體驗#親子共遊']
# 646
# not have
# ['#鐵道旅遊']
# 647
# not have
# 648
# other
# ['#無障礙#鐵道旅遊']
# 649
# not have
# 650
# other
# ['#送夕陽#生態體驗']
# 651
# not have
# ['#打卡熱點#生態體驗#親子共遊']
# 652
# not have
# 653
# other
# ['#無障礙#部落旅遊']
# 654
# not have
# 655
# other
# ['#無障礙#生態體驗']
# 656
# not have
# 657
# other
# ['#生態體驗#觀景平台']
# 658
# not have
# 659
# other
# 660
# other
# 661
# other
# 662
# other
# 663
# other
# 664
# other
# 665
# other
# 666
# other
# 667
# other
# 668
# other
# ['#無障礙#生態體驗#單車漫遊']
# 669
# not have
# 670
# other
# 671
# other
# 672
# other
# ['#生態體驗#登山步道#賞花']
# 673
# not have
# 674
# other
# ['#鐵道旅遊']
# 675
# not have
# 676
# other
# 677
# other
# ['#無障礙#生態體驗']
# 678
# not have
# ['#無障礙#生態體驗']
# 679
# not have
# 680
# other
# 681
# other
# ['#無障礙#生態體驗']
# 682
# not have
# ['#無障礙#網美必拍#部落旅遊#藝術']
# 683
# not have
# 684
# other
# 685
# other
# 686
# other
# ['#無障礙#生態體驗#親子共遊']
# 687
# not have
# 688
# other
# 689
# other
# 690
# other
# 691
# other
# ['#無障礙#單車漫遊#生態體驗#賞花#親子共遊']
# 692
# not have
# 693
# other
# 694
# other
# 695
# other
# ['#無障礙#生態體驗']
# 696
# not have
# 697
# other
# 698
# other
# 699
# other
# ['#無障礙#生態體驗#親子共遊#鐵道旅遊']
# 700
# not have
# 701
# other
# 702
# other
# 703
# other
# 704
# other
# 705
# other
# 706
# other
# 707
# other
# 708
# other
# 709
# other
# 710
# other
# 711
# other
# 712
# other
# 713
# other
# 714
# other
# 715
# other
# ['#無障礙#部落旅遊#親子共遊']
# 716
# not have
# 717
# other
# 718
# other
# 719
# other
# 720
# other
# 721
# other
# ['#無障礙#生態體驗']
# 722
# not have
# ['#無障礙#部落旅遊']
# 723
# not have
# 724
# other
# 725
# other
# 726
# other
# ['#無障礙#部落旅遊']
# 727
# not have
# 728
# other
# ['#無障礙#部落旅遊']
# 729
# not have
# ['#無障礙#戰地文化']
# 730
# not have
# ['#無障礙#戰地文化']
# 731
# not have
# ['#無障礙#部落旅遊']
# 732
# not have
# 733
# other
# 734
# other
# 735
# other
# 736
# other
# 737
# other
# 738
# other
# 739
# other
# 740
# other
# 741
# other
# 742
# other
# 743
# other
# 744
# other
# ['#無障礙#生態體驗#打卡熱點']
# 745
# not have
# 746
# other
# 747
# other
# ['#無障礙#生態體驗']
# 748
# not have
# 749
# other
# 750
# other
# 751
# other
# ['#無障礙#登山步道#生態體驗']
# 752
# not have
# 753
# other
# 754
# other

# %%
a=['#Oops!']

# %%
data_tag_process={}
data_tag_process['hash_tag']=[]

#data_tag_process['hash_tag'].extend(data_ok_1)

# %%
for i in tqdm(range(len(data_tag))):
    data_2020_ok=[data_tag[i]]
                       
    if '#網美必拍' in  data_2020_ok[0] and '#打卡熱點' in  data_2020_ok[0]:
        print(i)
        print('have_打卡熱點_process_1')
        data_process_1 = list(map(lambda data_2020_ok: data_2020_ok.replace('#網美必拍',''), data_2020_ok))        
        
        print(data_2020_ok)
        print(data_process_1)
        data_tag_process['hash_tag'].extend(data_process_1)
        #data_try['try_tag'].extend(data_process_1)
        #print(data_try['try_tag'])
        
    elif '#網美必拍' in  data_2020_ok[0] and '#打卡熱點' in  data_2020_ok[0]:
        print(i)
        print('have_打卡熱點_process_2')
        data_process_1 = list(map(lambda data_2020_ok: data_2020_ok.replace('#網美必拍',''), data_2020_ok))        
        
        print(data_2020_ok)
        print(data_process_1)
        data_tag_process['hash_tag'].extend(data_process_1)
        #data_try['try_tag'].extend(data_process_1)
        #print(data_try['try_tag'])
        
    elif '#網美必拍' in  data_2020_ok[0] or '#文青必訪' in  data_2020_ok[0]:
        print(i)
        print('have_打卡熱點_process_3')
        data_process_1 = list(map(lambda data_2020_ok: data_2020_ok.replace('#打卡熱點',''), data_2020_ok))        
        data_process_1 = list(map(lambda data_process_1: data_process_1.replace('#文青必訪','#打卡熱點'), data_process_1))
        data_process_1 = list(map(lambda data_process_1: data_process_1.replace('#網美必拍','#打卡熱點'), data_process_1))        
        #處理藝術->看展覽(符合以上條件下)
        data_process_1 = list(map(lambda data_process_1: data_process_1.replace('#藝術','#看展覽'), data_process_1))
        #吃海鮮->非吃不可(符合以上條下)
        data_process_1 = list(map(lambda data_process_1: data_process_1.replace('#吃海鮮','#非吃不可'), data_process_1))
        
        
        #水上活動->夏天戲水(符合以上條件下)(因為'#水上活動'與'夏天戲水'一起出現的情況只有一筆，所以直接處理)
         
        #data_process_1 = list(map(lambda data_process_1: data_process_1.replace('#夏天戲水',''), data_process_1))    
        #data_ok_3 = list(map(lambda data_process_1: data_process_1.replace('#水上活動','#夏天戲水'), data_process_1))    
        #print(data_2020_ok)
        #print(data_ok_3)
        
        if '#水上活動' in  data_process_1[0] and '#夏天戲水' in  data_process_1[0]:
            data_process_1 = list(map(lambda data_process_1: data_process_1.replace('#夏天戲水',''), data_process_1))    
            data_ok_3 = list(map(lambda data_process_1: data_process_1.replace('#水上活動','#夏天戲水'), data_process_1))    
            print(data_2020_ok)
            print(data_ok_3)
            data_tag_process['hash_tag'].extend(data_ok_3)
        elif '#水上活動' in  data_process_1[0] or '#夏天戲水' in  data_process_1[0]:
            data_ok_3 = list(map(lambda data_process_1: data_process_1.replace('#水上活動','#夏天戲水'), data_process_1))    
            print(data_2020_ok)
            print(data_ok_3)
            data_tag_process['hash_tag'].extend(data_ok_3)
        else :    
            print(0)
            data_tag_process['hash_tag'].extend(data_process_1)

        #data_try['try_tag'].extend(data_process_1)
        #print(data_try['try_tag']) 
    elif '#森林步道' in  data_2020_ok[0]:
        print(i)
        print('have_森林步道_process')
        data_process_1 = list(map(lambda data_2020_ok: data_2020_ok.replace('#森林步道','#登山步道'), data_2020_ok))        
        
        print(data_2020_ok)
        print(data_process_1)
        data_tag_process['hash_tag'].extend(data_process_1)
    #如果'#森林步道' 跟 '#登山步道'，一起出現時使用，經過檢查暫時還沒有出現這種情況    
    #elif '#森林步道' in  data_2020_ok[0] and '#登山步道' in  data_2020_ok[0]:
    #    print(i)
    #    print('have_森林步道_process')
    #    data_process_1 = list(map(lambda data_2020_ok: data_2020_ok.replace('#登山步道',''), data_2020_ok))        
    #    data_process_1 = list(map(lambda data_process_1: data_process_1.replace('#森林步道','#登山步道'), data_process_1))                
    #    print(data_2020_ok)
    #    print(data_process_1)        
        
    elif '#藝術' in  data_2020_ok[0]:
        print(i)
        print('have_藝術_process')
        data_process_1 = list(map(lambda data_2020_ok: data_2020_ok.replace('#藝術','#看展覽'), data_2020_ok))  
        data_process_1 = list(map(lambda data_process_1: data_process_1.replace('#水上活動','#夏天戲水'), data_process_1))
        
        
        print(data_2020_ok)
        print(data_process_1) 
        data_tag_process['hash_tag'].extend(data_process_1)

        
    elif '#水上活動' in  data_2020_ok[0] and '#夏天戲水' in  data_2020_ok[0]:
        print(i)
        print('have_水上活動_process_1')
        data_process_1 = list(map(lambda data_2020_ok: data_2020_ok.replace('#夏天戲水',''), data_2020_ok))        
        data_process_1 = list(map(lambda data_process_1: data_process_1.replace('#水上活動','#夏天戲水'), data_process_1))
        data_process_1 = list(map(lambda data_process_1: data_process_1.replace('#海灣旅遊','#看海景'), data_process_1))
        

        print(data_2020_ok)
        print(data_process_1)  
        data_tag_process['hash_tag'].extend(data_process_1)
        
    elif '#水上活動' in  data_2020_ok[0]:
        print(i)
        print('have_水上活動_process_2')
        data_process_1 = list(map(lambda data_2020_ok: data_2020_ok.replace('#水上活動','#夏天戲水'), data_2020_ok))        

        print(data_2020_ok)
        print(data_process_1)
        data_tag_process['hash_tag'].extend(data_process_1)
    elif '#吃海鮮' in  data_2020_ok[0]:
        print(i)
        print('have_吃海鮮_process')
        data_process_1 = list(map(lambda data_2020_ok: data_2020_ok.replace('#吃海鮮','#非吃不可'), data_2020_ok))          
        print(data_2020_ok)
        print(data_process_1)
        data_tag_process['hash_tag'].extend(data_process_1)
        
    elif '#海灣旅遊' in  data_2020_ok[0]:
        print(i)
        print('have_海灣旅遊_process')
        data_process_1 = list(map(lambda data_2020_ok: data_2020_ok.replace('#海灣旅遊','#看海景'), data_2020_ok))          
        print(data_2020_ok)
        print(data_process_1)
        data_tag_process['hash_tag'].extend(data_process_1)
        
    elif '#國家公園' in  data_2020_ok[0]:
        print(i)
        print('have_國家公園_process')
        data_process_1 = list(map(lambda data_2020_ok: data_2020_ok.replace('#國家公園','#國家風景區'), data_2020_ok))          
        print(data_2020_ok)
        print(data_process_1)
        data_tag_process['hash_tag'].extend(data_process_1)
        
    else :
        print(i)
        print('not have')
        data_tag_process['hash_tag'].extend(data_2020_ok)
# Out:
# HBox(children=(FloatProgress(value=0.0, max=755.0), HTML(value='')))
# 0
# not have
# 1
# not have
# 2
# not have
# 3
# not have
# 4
# have_打卡熱點_process_3
# ['#網美必拍#夏天戲水#單車漫遊#逛老街']
# ['#打卡熱點#夏天戲水#單車漫遊#逛老街']
# 5
# have_國家公園_process
# ['#賞花#生態體驗#登山步道#泡溫泉#國家公園']
# ['#賞花#生態體驗#登山步道#泡溫泉#國家風景區']
# 6
# not have
# 7
# not have
# 8
# not have
# 9
# not have
# 10
# not have
# 11
# not have
# 12
# not have
# 13
# not have
# 14
# not have
# 15
# not have
# 16
# not have
# 17
# not have
# 18
# not have
# 19
# not have
# 20
# not have
# 21
# not have
# 22
# not have
# 23
# have_水上活動_process_1
# ['#水上活動#夏天戲水#無障礙#迎曙光']
# ['#夏天戲水#無障礙#迎曙光']
# 24
# not have
# 25
# not have
# 26
# have_國家公園_process
# ['#生態體驗#地質奇觀#夏天戲水#國家公園']
# ['#生態體驗#地質奇觀#夏天戲水#國家風景區']
# 27
# have_國家公園_process
# ['#生態體驗#登山步道#國家公園']
# ['#生態體驗#登山步道#國家風景區']
# 28
# not have
# 29
# not have
# 30
# not have
# 31
# have_海灣旅遊_process
# ['#無障礙#單車漫遊#夏天戲水#海灣旅遊#國家風景區']
# ['#無障礙#單車漫遊#夏天戲水#看海景#國家風景區']
# 32
# not have
# 33
# not have
# 34
# not have
# 35
# not have
# 36
# have_藝術_process
# ['#浪漫約會#生態體驗#藝術']
# ['#浪漫約會#生態體驗#看展覽']
# 37
# not have
# 38
# have_森林步道_process
# ['#森林步道#生態體驗#打卡熱點']
# ['#登山步道#生態體驗#打卡熱點']
# 39
# not have
# 40
# not have
# 41
# have_森林步道_process
# ['#賞花#迎曙光#森林步道#無障礙']
# ['#賞花#迎曙光#登山步道#無障礙']
# 42
# not have
# 43
# not have
# 44
# not have
# 45
# not have
# 46
# not have
# 47
# not have
# 48
# not have
# 49
# not have
# 50
# have_森林步道_process
# ['#森林步道#賞花']
# ['#登山步道#賞花']
# 51
# not have
# 52
# not have
# 53
# not have
# 54
# not have
# 55
# not have
# 56
# not have
# 57
# not have
# 58
# not have
# 59
# not have
# 60
# have_國家公園_process
# ['#登山步道#生態體驗#國家公園']
# ['#登山步道#生態體驗#國家風景區']
# 61
# not have
# 62
# not have
# 63
# not have
# 64
# have_森林步道_process
# ['#森林步道#泡溫泉#生態體驗']
# ['#登山步道#泡溫泉#生態體驗']
# 65
# not have
# 66
# have_打卡熱點_process_3
# 0
# 67
# have_藝術_process
# ['#博物館#藝術']
# ['#博物館#看展覽']
# 68
# have_森林步道_process
# ['#生態體驗#森林步道#賞花']
# ['#生態體驗#登山步道#賞花']
# 69
# not have
# 70
# not have
# 71
# not have
# 72
# not have
# 73
# not have
# 74
# not have
# 75
# not have
# 76
# not have
# 77
# not have
# 78
# have_森林步道_process
# ['#賞花#迎曙光#無障礙#森林步道#國家風景區']
# ['#賞花#迎曙光#無障礙#登山步道#國家風景區']
# 79
# not have
# 80
# not have
# 81
# not have
# 82
# not have
# 83
# not have
# 84
# have_吃海鮮_process
# ['#吃海鮮#看海景#親子共遊']
# ['#非吃不可#看海景#親子共遊']
# 85
# not have
# 86
# not have
# 87
# not have
# 88
# not have
# 89
# have_森林步道_process
# ['#森林步道#生態體驗#迎曙光#賞花']
# ['#登山步道#生態體驗#迎曙光#賞花']
# 90
# have_打卡熱點_process_1
# ['#打卡熱點#網美必拍#單車漫遊#親子共遊']
# ['#打卡熱點#單車漫遊#親子共遊']
# 91
# not have
# 92
# not have
# 93
# not have
# 94
# have_吃海鮮_process
# ['#看海景#打卡熱點#吃海鮮']
# ['#看海景#打卡熱點#非吃不可']
# 95
# not have
# 96
# not have
# 97
# not have
# 98
# have_水上活動_process_1
# ['#水上活動#夏天戲水#無障礙#海灣旅遊#親子共遊']
# ['#夏天戲水#無障礙#看海景#親子共遊']
# 99
# not have
# 100
# not have
# 101
# not have
# 102
# not have
# 103
# have_森林步道_process
# ['#生態體驗#森林步道#觀景平台#親子共遊']
# ['#生態體驗#登山步道#觀景平台#親子共遊']
# 104
# have_水上活動_process_2
# ['#打卡熱點#水上活動#泡溫泉#生態體驗']
# ['#打卡熱點#夏天戲水#泡溫泉#生態體驗']
# 105
# not have
# 106
# not have
# 107
# not have
# 108
# not have
# 109
# not have
# 110
# not have
# 111
# not have
# 112
# not have
# 113
# not have
# 114
# not have
# 115
# not have
# 116
# not have
# 117
# not have
# 118
# not have
# 119
# not have
# 120
# not have
# 121
# not have
# 122
# not have
# 123
# have_藝術_process
# ['#藝術#打卡熱點']
# ['#看展覽#打卡熱點']
# 124
# not have
# 125
# not have
# 126
# not have
# 127
# not have
# 128
# have_打卡熱點_process_1
# ['#博物館#看展覽#打卡熱點#網美必拍']
# ['#博物館#看展覽#打卡熱點']
# 129
# not have
# 130
# not have
# 131
# not have
# 132
# not have
# 133
# not have
# 134
# not have
# 135
# not have
# 136
# not have
# 137
# not have
# 138
# not have
# 139
# not have
# 140
# not have
# 141
# not have
# 142
# not have
# 143
# have_打卡熱點_process_3
# 0
# 144
# not have
# 145
# not have
# 146
# not have
# 147
# not have
# 148
# have_海灣旅遊_process
# ['#親子共遊#夏天戲水#海灣旅遊']
# ['#親子共遊#夏天戲水#看海景']
# 149
# have_森林步道_process
# ['#地質奇觀#森林步道']
# ['#地質奇觀#登山步道']
# 150
# not have
# 151
# not have
# 152
# not have
# 153
# not have
# 154
# not have
# 155
# not have
# 156
# not have
# 157
# not have
# 158
# have_打卡熱點_process_1
# ['#打卡熱點#地質奇觀#網美必拍#觀景平台']
# ['#打卡熱點#地質奇觀#觀景平台']
# 159
# not have
# 160
# not have
# 161
# not have
# 162
# not have
# 163
# have_藝術_process
# ['#賞花#藝術']
# ['#賞花#看展覽']
# 164
# not have
# 165
# not have
# 166
# not have
# 167
# not have
# 168
# not have
# 169
# not have
# 170
# not have
# 171
# not have
# 172
# not have
# 173
# not have
# 174
# have_海灣旅遊_process
# ['#親子共遊#夏天戲水#海灣旅遊#無障礙']
# ['#親子共遊#夏天戲水#看海景#無障礙']
# 175
# have_海灣旅遊_process
# ['#海灣旅遊']
# ['#看海景']
# 176
# not have
# 177
# not have
# 178
# not have
# 179
# not have
# 180
# not have
# 181
# not have
# 182
# not have
# 183
# not have
# 184
# not have
# 185
# not have
# 186
# not have
# 187
# not have
# 188
# not have
# 189
# not have
# 190
# not have
# 191
# not have
# 192
# not have
# 193
# have_森林步道_process
# ['#森林步道#親子共遊#生態體驗']
# ['#登山步道#親子共遊#生態體驗']
# 194
# not have
# 195
# not have
# 196
# not have
# 197
# have_水上活動_process_2
# ['#單車漫遊#生態體驗#水上活動']
# ['#單車漫遊#生態體驗#夏天戲水']
# 198
# have_藝術_process
# ['#無障礙#藝術']
# ['#無障礙#看展覽']
# 199
# not have
# 200
# not have
# 201
# not have
# 202
# have_藝術_process
# ['#打卡熱點#藝術']
# ['#打卡熱點#看展覽']
# 203
# not have
# 204
# have_森林步道_process
# ['#生態體驗#森林步道']
# ['#生態體驗#登山步道']
# 205
# have_藝術_process
# ['#博物館#藝術']
# ['#博物館#看展覽']
# 206
# not have
# 207
# not have
# 208
# have_海灣旅遊_process
# ['#海灣旅遊#夏天戲水#打卡熱點']
# ['#看海景#夏天戲水#打卡熱點']
# 209
# not have
# 210
# not have
# 211
# not have
# 212
# not have
# 213
# not have
# 214
# not have
# 215
# not have
# 216
# have_打卡熱點_process_3
# 0
# 217
# not have
# 218
# not have
# 219
# not have
# 220
# not have
# 221
# have_森林步道_process
# ['#森林步道#生態體驗']
# ['#登山步道#生態體驗']
# 222
# not have
# 223
# not have
# 224
# have_藝術_process
# ['#看展覽#博物館#藝術#親子共遊']
# ['#看展覽#博物館#看展覽#親子共遊']
# 225
# not have
# 226
# not have
# 227
# not have
# 228
# not have
# 229
# have_海灣旅遊_process
# ['#地質奇觀#打卡熱點#海灣旅遊']
# ['#地質奇觀#打卡熱點#看海景']
# 230
# not have
# 231
# not have
# 232
# not have
# 233
# not have
# 234
# not have
# 235
# not have
# 236
# have_森林步道_process
# ['#森林步道#泡溫泉#生態體驗']
# ['#登山步道#泡溫泉#生態體驗']
# 237
# not have
# 238
# not have
# 239
# not have
# 240
# not have
# 241
# not have
# 242
# have_森林步道_process
# ['#生態體驗#賞花#森林步道']
# ['#生態體驗#賞花#登山步道']
# 243
# not have
# 244
# have_藝術_process
# ['#藝術#親子共遊#看展覽']
# ['#看展覽#親子共遊#看展覽']
# 245
# have_打卡熱點_process_1
# ['#博物館#打卡熱點#網美必拍#看展覽']
# ['#博物館#打卡熱點#看展覽']
# 246
# have_森林步道_process
# ['#泡溫泉#生態體驗#森林步道']
# ['#泡溫泉#生態體驗#登山步道']
# 247
# not have
# 248
# not have
# 249
# not have
# 250
# not have
# 251
# not have
# 252
# not have
# 253
# not have
# 254
# not have
# 255
# have_森林步道_process
# ['#森林步道#生態體驗']
# ['#登山步道#生態體驗']
# 256
# not have
# 257
# not have
# 258
# not have
# 259
# not have
# 260
# not have
# 261
# not have
# 262
# not have
# 263
# not have
# 264
# have_打卡熱點_process_3
# 0
# 265
# have_水上活動_process_1
# ['#水上活動#夏天戲水#海灣旅遊']
# ['#夏天戲水#看海景']
# 266
# not have
# 267
# not have
# 268
# have_打卡熱點_process_3
# 0
# 269
# have_打卡熱點_process_3
# 0
# 270
# have_打卡熱點_process_3
# 0
# 271
# not have
# 272
# have_國家公園_process
# ['#古蹟巡禮#戰地文化#生態體驗#國家公園']
# ['#古蹟巡禮#戰地文化#生態體驗#國家風景區']
# 273
# not have
# 274
# have_國家公園_process
# ['#生態體驗#無障礙#國家公園']
# ['#生態體驗#無障礙#國家風景區']
# 275
# not have
# 276
# have_國家公園_process
# ['#登山步道#生態體驗#國家公園']
# ['#登山步道#生態體驗#國家風景區']
# 277
# not have
# 278
# not have
# 279
# not have
# 280
# not have
# 281
# have_藝術_process
# ['#藝術']
# ['#看展覽']
# 282
# have_打卡熱點_process_3
# 0
# 283
# not have
# 284
# not have
# 285
# not have
# 286
# have_打卡熱點_process_3
# 0
# 287
# have_藝術_process
# ['#打卡熱點#藝術#看展覽#無障礙']
# ['#打卡熱點#看展覽#看展覽#無障礙']
# 288
# not have
# 289
# not have
# 290
# not have
# 291
# not have
# 292
# not have
# 293
# not have
# 294
# not have
# 295
# not have
# 296
# not have
# 297
# not have
# 298
# have_吃海鮮_process
# ['#看海景#吃海鮮']
# ['#看海景#非吃不可']
# 299
# not have
# 300
# not have
# 301
# not have
# 302
# not have
# 303
# not have
# 304
# not have
# 305
# not have
# 306
# not have
# 307
# not have
# 308
# not have
# 309
# not have
# 310
# not have
# 311
# not have
# 312
# not have
# 313
# have_打卡熱點_process_3
# 0
# 314
# not have
# 315
# have_森林步道_process
# ['#泡溫泉#生態體驗#森林步道']
# ['#泡溫泉#生態體驗#登山步道']
# 316
# have_國家公園_process
# ['#生態體驗#登山步道#國家公園#無障礙']
# ['#生態體驗#登山步道#國家風景區#無障礙']
# 317
# not have
# 318
# not have
# 319
# have_打卡熱點_process_3
# 0
# 320
# not have
# 321
# not have
# 322
# not have
# 323
# not have
# 324
# not have
# 325
# not have
# 326
# not have
# 327
# not have
# 328
# have_打卡熱點_process_3
# 0
# 329
# not have
# 330
# not have
# 331
# not have
# 332
# not have
# 333
# have_吃海鮮_process
# ['#吃海鮮#看海景#親子共遊']
# ['#非吃不可#看海景#親子共遊']
# 334
# have_藝術_process
# ['#博物館#藝術']
# ['#博物館#看展覽']
# 335
# not have
# 336
# not have
# 337
# not have
# 338
# not have
# 339
# not have
# 340
# have_藝術_process
# ['#水上活動#藝術']
# ['#夏天戲水#看展覽']
# 341
# not have
# 342
# have_吃海鮮_process
# ['#親子共遊#送夕陽#吃海鮮']
# ['#親子共遊#送夕陽#非吃不可']
# 343
# have_森林步道_process
# ['#賞花#森林步道#親子共遊']
# ['#賞花#登山步道#親子共遊']
# 344
# not have
# 345
# have_藝術_process
# ['#單車漫遊#博物館#藝術']
# ['#單車漫遊#博物館#看展覽']
# 346
# not have
# 347
# have_藝術_process
# ['#藝術#親子共遊']
# ['#看展覽#親子共遊']
# 348
# not have
# 349
# not have
# 350
# have_打卡熱點_process_3
# 0
# 351
# not have
# 352
# not have
# 353
# not have
# 354
# not have
# 355
# not have
# 356
# not have
# 357
# not have
# 358
# not have
# 359
# not have
# 360
# not have
# 361
# not have
# 362
# not have
# 363
# not have
# 364
# not have
# 365
# not have
# 366
# not have
# 367
# have_藝術_process
# ['#藝術#看展覽#打卡熱點']
# ['#看展覽#看展覽#打卡熱點']
# 368
# not have
# 369
# not have
# 370
# not have
# 371
# not have
# 372
# not have
# 373
# not have
# 374
# not have
# 375
# not have
# 376
# not have
# 377
# not have
# 378
# have_水上活動_process_2
# ['#水上活動']
# ['#夏天戲水']
# 379
# not have
# 380
# not have
# 381
# not have
# 382
# not have
# 383
# not have
# 384
# have_打卡熱點_process_3
# 0
# 385
# not have
# 386
# have_打卡熱點_process_3
# 0
# 387
# not have
# 388
# not have
# 389
# not have
# 390
# not have
# 391
# not have
# 392
# not have
# 393
# not have
# 394
# not have
# 395
# not have
# 396
# not have
# 397
# not have
# 398
# have_海灣旅遊_process
# ['#海灣旅遊#無障礙#夏天戲水#生態體驗#國家風景區']
# ['#看海景#無障礙#夏天戲水#生態體驗#國家風景區']
# 399
# not have
# 400
# not have
# 401
# not have
# 402
# not have
# 403
# not have
# 404
# not have
# 405
# not have
# 406
# not have
# 407
# not have
# 408
# not have
# 409
# not have
# 410
# not have
# 411
# not have
# 412
# not have
# 413
# have_藝術_process
# ['#藝術#看展覽#親子共遊']
# ['#看展覽#看展覽#親子共遊']
# 414
# not have
# 415
# not have
# 416
# not have
# 417
# have_水上活動_process_2
# ['#部落旅遊#生態體驗#水上活動#單車漫遊']
# ['#部落旅遊#生態體驗#夏天戲水#單車漫遊']
# 418
# not have
# 419
# not have
# 420
# have_吃海鮮_process
# ['#吃海鮮#看海景']
# ['#非吃不可#看海景']
# 421
# not have
# 422
# not have
# 423
# not have
# 424
# have_森林步道_process
# ['#夏天戲水#親子共遊#森林步道#賞花']
# ['#夏天戲水#親子共遊#登山步道#賞花']
# 425
# not have
# 426
# not have
# 427
# not have
# 428
# not have
# 429
# not have
# 430
# not have
# 431
# not have
# 432
# not have
# 433
# not have
# 434
# not have
# 435
# not have
# 436
# have_藝術_process
# ['#藝術#看展覽#親子共遊']
# ['#看展覽#看展覽#親子共遊']
# 437
# not have
# 438
# not have
# 439
# not have
# 440
# not have
# 441
# not have
# 442
# not have
# 443
# not have
# 444
# not have
# 445
# not have
# 446
# not have
# 447
# not have
# 448
# not have
# 449
# not have
# 450
# not have
# 451
# not have
# 452
# have_藝術_process
# ['#看展覽#藝術']
# ['#看展覽#看展覽']
# 453
# not have
# 454
# not have
# 455
# not have
# 456
# not have
# 457
# not have
# 458
# not have
# 459
# have_藝術_process
# ['#藝術']
# ['#看展覽']
# 460
# not have
# 461
# not have
# 462
# not have
# 463
# have_水上活動_process_2
# ['#水上活動#生態體驗#親子共遊']
# ['#夏天戲水#生態體驗#親子共遊']
# 464
# have_打卡熱點_process_3
# 0
# 465
# not have
# 466
# not have
# 467
# not have
# 468
# not have
# 469
# not have
# 470
# not have
# 471
# not have
# 472
# not have
# 473
# not have
# 474
# not have
# 475
# have_森林步道_process
# ['#生態體驗#森林步道#親子共遊']
# ['#生態體驗#登山步道#親子共遊']
# 476
# not have
# 477
# not have
# 478
# not have
# 479
# not have
# 480
# not have
# 481
# not have
# 482
# not have
# 483
# not have
# 484
# not have
# 485
# not have
# 486
# not have
# 487
# not have
# 488
# not have
# 489
# not have
# 490
# not have
# 491
# not have
# 492
# not have
# 493
# have_藝術_process
# ['#藝術#看展覽#親子共遊']
# ['#看展覽#看展覽#親子共遊']
# 494
# have_打卡熱點_process_1
# ['#打卡熱點#網美必拍#拍婚紗#燈塔']
# ['#打卡熱點#拍婚紗#燈塔']
# 495
# not have
# 496
# not have
# 497
# not have
# 498
# not have
# 499
# have_森林步道_process
# ['#生態體驗#親子共遊#森林步道']
# ['#生態體驗#親子共遊#登山步道']
# 500
# not have
# 501
# not have
# 502
# not have
# 503
# not have
# 504
# not have
# 505
# not have
# 506
# have_打卡熱點_process_3
# 0
# 507
# not have
# 508
# not have
# 509
# not have
# 510
# not have
# 511
# not have
# 512
# have_藝術_process
# ['#博物館#看展覽#藝術']
# ['#博物館#看展覽#看展覽']
# 513
# not have
# 514
# not have
# 515
# not have
# 516
# not have
# 517
# not have
# 518
# not have
# 519
# have_打卡熱點_process_3
# 0
# 520
# not have
# 521
# have_藝術_process
# ['#藝術#看展覽#親子共遊']
# ['#看展覽#看展覽#親子共遊']
# 522
# not have
# 523
# not have
# 524
# not have
# 525
# not have
# 526
# not have
# 527
# not have
# 528
# not have
# 529
# not have
# 530
# have_森林步道_process
# ['#森林步道#生態體驗']
# ['#登山步道#生態體驗']
# 531
# not have
# 532
# not have
# 533
# not have
# 534
# not have
# 535
# not have
# 536
# not have
# 537
# not have
# 538
# have_打卡熱點_process_3
# 0
# 539
# not have
# 540
# not have
# 541
# have_藝術_process
# ['#藝術']
# ['#看展覽']
# 542
# have_藝術_process
# ['#看展覽#藝術']
# ['#看展覽#看展覽']
# 543
# not have
# 544
# not have
# 545
# not have
# 546
# not have
# 547
# not have
# 548
# not have
# 549
# have_藝術_process
# ['#看展覽#博物館#藝術']
# ['#看展覽#博物館#看展覽']
# 550
# not have
# 551
# not have
# 552
# not have
# 553
# have_藝術_process
# ['#藝術#打卡熱點']
# ['#看展覽#打卡熱點']
# 554
# not have
# 555
# not have
# 556
# not have
# 557
# not have
# 558
# not have
# 559
# not have
# 560
# have_藝術_process
# ['#藝術#生態體驗#賞花']
# ['#看展覽#生態體驗#賞花']
# 561
# not have
# 562
# not have
# 563
# not have
# 564
# not have
# 565
# not have
# 566
# not have
# 567
# have_藝術_process
# ['#藝術#看展覽']
# ['#看展覽#看展覽']
# 568
# not have
# 569
# not have
# 570
# not have
# 571
# not have
# 572
# not have
# 573
# not have
# 574
# have_水上活動_process_1
# ['#夏天戲水#水上活動#生態體驗#親子共遊']
# ['#夏天戲水#生態體驗#親子共遊']
# 575
# not have
# 576
# not have
# 577
# not have
# 578
# not have
# 579
# not have
# 580
# not have
# 581
# not have
# 582
# not have
# 583
# not have
# 584
# not have
# 585
# not have
# 586
# not have
# 587
# have_打卡熱點_process_1
# ['#網美必拍#打卡熱點#親子共遊']
# ['#打卡熱點#親子共遊']
# 588
# not have
# 589
# not have
# 590
# not have
# 591
# have_藝術_process
# ['#藝術']
# ['#看展覽']
# 592
# have_打卡熱點_process_3
# 0
# 593
# not have
# 594
# not have
# 595
# not have
# 596
# not have
# 597
# not have
# 598
# not have
# 599
# not have
# 600
# not have
# 601
# not have
# 602
# not have
# 603
# not have
# 604
# not have
# 605
# not have
# 606
# have_打卡熱點_process_3
# 0
# 607
# not have
# 608
# not have
# 609
# not have
# 610
# not have
# 611
# not have
# 612
# not have
# 613
# not have
# 614
# not have
# 615
# have_打卡熱點_process_1
# ['#打卡熱點#網美必拍']
# ['#打卡熱點']
# 616
# not have
# 617
# not have
# 618
# not have
# 619
# have_打卡熱點_process_3
# 0
# 620
# have_藝術_process
# ['#打卡熱點#看展覽#藝術']
# ['#打卡熱點#看展覽#看展覽']
# 621
# not have
# 622
# have_吃海鮮_process
# ['#送夕陽#吃海鮮#看海景']
# ['#送夕陽#非吃不可#看海景']
# 623
# not have
# 624
# not have
# 625
# not have
# 626
# not have
# 627
# have_吃海鮮_process
# ['#賞夜景#單車漫遊#觀景平台#吃海鮮']
# ['#賞夜景#單車漫遊#觀景平台#非吃不可']
# 628
# not have
# 629
# not have
# 630
# have_打卡熱點_process_3
# 0
# 631
# not have
# 632
# not have
# 633
# have_打卡熱點_process_3
# 0
# 634
# have_吃海鮮_process
# ['#親子共遊#賞夜景#吃海鮮']
# ['#親子共遊#賞夜景#非吃不可']
# 635
# not have
# 636
# have_吃海鮮_process
# ['#送夕陽#吃海鮮#看海景#親子共遊']
# ['#送夕陽#非吃不可#看海景#親子共遊']
# 637
# not have
# 638
# not have
# 639
# not have
# 640
# have_打卡熱點_process_3
# ['#無障礙#夏天戲水#吃海鮮#網美必拍']
# ['#無障礙#夏天戲水#非吃不可#打卡熱點']
# 641
# have_打卡熱點_process_1
# ['#無障礙#打卡熱點#網美必拍#單車漫遊']
# ['#無障礙#打卡熱點#單車漫遊']
# 642
# not have
# 643
# have_吃海鮮_process
# ['#非吃不可#吃海鮮#看海景']
# ['#非吃不可#非吃不可#看海景']
# 644
# not have
# 645
# have_打卡熱點_process_3
# 0
# 646
# not have
# 647
# not have
# 648
# not have
# 649
# not have
# 650
# not have
# 651
# not have
# 652
# not have
# 653
# not have
# 654
# not have
# 655
# not have
# 656
# not have
# 657
# have_打卡熱點_process_3
# 0
# 658
# not have
# 659
# not have
# 660
# not have
# 661
# not have
# 662
# have_吃海鮮_process
# ['#無障礙#吃海鮮']
# ['#無障礙#非吃不可']
# 663
# have_打卡熱點_process_3
# 0
# 664
# have_打卡熱點_process_3
# 0
# 665
# not have
# 666
# not have
# 667
# not have
# 668
# have_打卡熱點_process_3
# 0
# 669
# not have
# 670
# not have
# 671
# not have
# 672
# not have
# 673
# not have
# 674
# not have
# 675
# not have
# 676
# not have
# 677
# have_打卡熱點_process_3
# 0
# 678
# not have
# 679
# not have
# 680
# not have
# 681
# have_打卡熱點_process_3
# 0
# 682
# not have
# 683
# have_打卡熱點_process_3
# 0
# 684
# not have
# 685
# not have
# 686
# not have
# 687
# not have
# 688
# not have
# 689
# not have
# 690
# not have
# 691
# have_水上活動_process_2
# ['#無障礙#水上活動']
# ['#無障礙#夏天戲水']
# 692
# not have
# 693
# not have
# 694
# not have
# 695
# not have
# 696
# not have
# 697
# not have
# 698
# not have
# 699
# not have
# 700
# not have
# 701
# have_打卡熱點_process_3
# 0
# 702
# not have
# 703
# not have
# 704
# not have
# 705
# not have
# 706
# have_打卡熱點_process_3
# 0
# 707
# have_打卡熱點_process_3
# ['#無障礙#水上活動#夏天戲水#網美必拍']
# ['#無障礙#夏天戲水#打卡熱點']
# 708
# not have
# 709
# not have
# 710
# not have
# 711
# not have
# 712
# not have
# 713
# not have
# 714
# not have
# 715
# not have
# 716
# not have
# 717
# not have
# 718
# not have
# 719
# not have
# 720
# not have
# 721
# not have
# 722
# not have
# 723
# not have
# 724
# have_藝術_process
# ['#無障礙#親子共遊#藝術']
# ['#無障礙#親子共遊#看展覽']
# 725
# not have
# 726
# not have
# 727
# not have
# 728
# not have
# 729
# not have
# 730
# not have
# 731
# not have
# 732
# not have
# 733
# have_打卡熱點_process_3
# 0
# 734
# not have
# 735
# not have
# 736
# not have
# 737
# not have
# 738
# not have
# 739
# not have
# 740
# not have
# 741
# not have
# 742
# have_打卡熱點_process_3
# 0
# 743
# not have
# 744
# not have
# 745
# not have
# 746
# not have
# 747
# not have
# 748
# not have
# 749
# not have
# 750
# not have
# 751
# not have
# 752
# not have
# 753
# not have
# 754
# not have

# %%
result=pd.DataFrame.from_dict(data_tag_process)

# %%
result
# Out:
#                       hash_tag
# 0                #逛老街#賞夜景#非吃不可
# 1                    #逛老街#非吃不可
# 2               #打卡熱點#非吃不可#逛夜市
# 3           #地質奇觀#打卡熱點#拍婚紗#無障礙
# 4          #打卡熱點#夏天戲水#單車漫遊#逛老街
# 5      #賞花#生態體驗#登山步道#泡溫泉#國家風景區
# 6                #泡溫泉#生態體驗#逛老街
# 7          #浪漫約會#送夕陽#親子共遊#夏天戲水
# 8                #看展覽#博物館#親子共遊
# 9              #寺廟祈福#打卡熱點#古蹟巡禮
# 10                  #打卡熱點#單車漫遊
# 11                   #非吃不可#逛夜市
# 12         #生態體驗#打卡熱點#送夕陽#浪漫約會
# 13                  #地質奇觀#觀景平台
# 14    #無障礙#拍婚紗#單車漫遊#觀景平台#國家風景區
# 15                   #逛老街#鐵道旅遊
# 16             #古蹟巡禮#鐵道旅遊#打卡熱點
# 17         #單車漫遊#親子共遊#浪漫約會#賞夜景
# 18                   #泡溫泉#親子共遊
# 19                   #非吃不可#逛夜市
# 20               #逛老街#泡溫泉#單車漫遊
# 21              #逛夜市#非吃不可#親子共遊
# 22               #生態體驗#逛老街#無障礙
# 23               #夏天戲水#無障礙#迎曙光
# 24   #部落旅遊#生態體驗#無障礙#單車漫遊#國家風景區
# 25                   #打卡熱點#賞夜景
# 26       #生態體驗#地質奇觀#夏天戲水#國家風景區
# 27            #生態體驗#登山步道#國家風景區
# 28                  #生態體驗#觀景平台
# 29                  #古蹟巡禮#戰地文化
# ..                         ...
# 725                  #無障礙#親子共遊
# 726                       #無障礙
# 727                  #無障礙#部落旅遊
# 728                       #無障礙
# 729                  #無障礙#部落旅遊
# 730                  #無障礙#戰地文化
# 731                  #無障礙#戰地文化
# 732                  #無障礙#部落旅遊
# 733                   #打卡熱點#燈塔
# 734                      #親子共遊
# 735                      #親子共遊
# 736                       #博物館
# 737                       #逛老街
# 738                      #親子共遊
# 739                  #博物館#親子共遊
# 740                      #古蹟巡禮
# 741                       #博物館
# 742                  #無障礙#打卡熱點
# 743         #無障礙#漫遊客庄#看展覽#親子共遊
# 744                  #無障礙#親子共遊
# 745             #無障礙#生態體驗#打卡熱點
# 746                  #無障礙#漫遊客庄
# 747              #無障礙#看展覽#漫遊客庄
# 748                  #無障礙#生態體驗
# 749               #無障礙#看展覽#博物館
# 750              #無障礙#漫遊客庄#看展覽
# 751                  #無障礙#漫遊客庄
# 752             #無障礙#登山步道#生態體驗
# 753                  #無障礙#單車漫遊
# 754             #無障礙#漫遊客庄#寺廟祈福
#
# [755 rows x 1 columns]

# %%
result.to_csv('tag_process_剩下不需要的tag.csv',index=False)

# %% [markdown]
# # 資料處理_備份

# %%
for i in tqdm(range(len(data_tag))):
    data_2020_ok=[data_tag[i]]
    if '#網美必拍' in  data_2020_ok[0] and '#打卡熱點' in  data_2020_ok[0]:
        print(i)
        print('have_打卡熱點_process_1')
        data_process_1 = list(map(lambda data_2020_ok: data_2020_ok.replace('#網美必拍',''), data_2020_ok))        
        
        print(data_2020_ok)
        print(data_process_1)
        #data_try['try_tag'].extend(data_process_1)
        #print(data_try['try_tag'])
        
    elif '#網美必拍' in  data_2020_ok[0] and '#打卡熱點' in  data_2020_ok[0]:
        print(i)
        print('have_打卡熱點_process_2')
        data_process_1 = list(map(lambda data_2020_ok: data_2020_ok.replace('#網美必拍',''), data_2020_ok))        
        
        print(data_2020_ok)
        print(data_process_1)
        #data_try['try_tag'].extend(data_process_1)
        #print(data_try['try_tag'])
        
    elif '#網美必拍' in  data_2020_ok[0] or '#文青必訪' in  data_2020_ok[0]:
        print(i)
        print('have_打卡熱點_process_3')
        data_process_1 = list(map(lambda data_2020_ok: data_2020_ok.replace('#打卡熱點',''), data_2020_ok))        
        data_process_1 = list(map(lambda data_process_1: data_process_1.replace('#文青必訪','#打卡熱點'), data_process_1))
        data_ok_3 = list(map(lambda data_process_1: data_process_1.replace('#網美必拍','#打卡熱點'), data_process_1))        
        
        print(data_2020_ok)
        print(data_ok_3)
        #data_try['try_tag'].extend(data_process_1)
        #print(data_try['try_tag']) 
    elif '#森林步道' in  data_2020_ok[0]:
        print(i)
        print('have_森林步道_process')
        data_process_1 = list(map(lambda data_2020_ok: data_2020_ok.replace('#森林步道','#登山步道'), data_2020_ok))        
        
        print(data_2020_ok)
        print(data_process_1)
    #如果'#森林步道' 跟 '#登山步道'，一起出現時使用，經過檢查暫時還沒有出現這種情況    
    #elif '#森林步道' in  data_2020_ok[0] and '#登山步道' in  data_2020_ok[0]:
    #    print(i)
    #    print('have_森林步道_process')
    #    data_process_1 = list(map(lambda data_2020_ok: data_2020_ok.replace('#登山步道',''), data_2020_ok))        
    #    data_process_1 = list(map(lambda data_process_1: data_process_1.replace('#森林步道','#登山步道'), data_process_1))                
    #    print(data_2020_ok)
    #    print(data_process_1)        
        
    elif '#藝術' in  data_2020_ok[0]:
        print(i)
        print('have_藝術_process')
        data_process_1 = list(map(lambda data_2020_ok: data_2020_ok.replace('#藝術','#看展覽'), data_2020_ok))        
        
        print(data_2020_ok)
        print(data_process_1)        
        
    else :
        print(i)
        print('not have')
        #print(data_2020_ok)

# %% [markdown]
# # 備份_2

# %%
for i in tqdm(range(len(data_tag))):
    data_2020_ok=[data_tag[i]]
    if '#網美必拍' in  data_2020_ok[0] and '#打卡熱點' in  data_2020_ok[0]:
        print(i)
        print('have_打卡熱點_process_1')
        data_process_1 = list(map(lambda data_2020_ok: data_2020_ok.replace('#網美必拍',''), data_2020_ok))        
        
        print(data_2020_ok)
        print(data_process_1)
        #data_try['try_tag'].extend(data_process_1)
        #print(data_try['try_tag'])
        
    elif '#網美必拍' in  data_2020_ok[0] and '#打卡熱點' in  data_2020_ok[0]:
        print(i)
        print('have_打卡熱點_process_2')
        data_process_1 = list(map(lambda data_2020_ok: data_2020_ok.replace('#網美必拍',''), data_2020_ok))        
        
        print(data_2020_ok)
        print(data_process_1)
        #data_try['try_tag'].extend(data_process_1)
        #print(data_try['try_tag'])
        
    elif '#網美必拍' in  data_2020_ok[0] or '#文青必訪' in  data_2020_ok[0]:
        print(i)
        print('have_打卡熱點_process_3')
        data_process_1 = list(map(lambda data_2020_ok: data_2020_ok.replace('#打卡熱點',''), data_2020_ok))        
        data_process_1 = list(map(lambda data_process_1: data_process_1.replace('#文青必訪','#打卡熱點'), data_process_1))
        data_process_1 = list(map(lambda data_process_1: data_process_1.replace('#網美必拍','#打卡熱點'), data_process_1))        
        #處理藝術->看展覽(符合以上條件下)
        data_process_1 = list(map(lambda data_process_1: data_process_1.replace('#藝術','#看展覽'), data_process_1))
        #吃海鮮->非吃不可(符合以上條下)
        data_process_1 = list(map(lambda data_process_1: data_process_1.replace('#吃海鮮','#非吃不可'), data_process_1))
        
        
        #水上活動->夏天戲水(符合以上條件下)(因為'#水上活動'與'夏天戲水'一起出現的情況只有一筆，所以直接處理)
         
        #data_process_1 = list(map(lambda data_process_1: data_process_1.replace('#夏天戲水',''), data_process_1))    
        #data_ok_3 = list(map(lambda data_process_1: data_process_1.replace('#水上活動','#夏天戲水'), data_process_1))    
        #print(data_2020_ok)
        #print(data_ok_3)
        
        if '#水上活動' in  data_process_1[0] and '#夏天戲水' in  data_process_1[0]:
            data_process_1 = list(map(lambda data_process_1: data_process_1.replace('#夏天戲水',''), data_process_1))    
            data_ok_3 = list(map(lambda data_process_1: data_process_1.replace('#水上活動','#夏天戲水'), data_process_1))    
            print(data_2020_ok)
            print(data_ok_3)
        elif '#水上活動' in  data_process_1[0] or '#夏天戲水' in  data_process_1[0]:
            data_ok_3 = list(map(lambda data_process_1: data_process_1.replace('#水上活動','#夏天戲水'), data_process_1))    
            print(data_2020_ok)
            print(data_ok_3)
        else :    
            print(0)
            data_tag_process['hash_tag'].extend(data_process_1)

        #data_try['try_tag'].extend(data_process_1)
        #print(data_try['try_tag']) 
    elif '#森林步道' in  data_2020_ok[0]:
        print(i)
        print('have_森林步道_process')
        data_process_1 = list(map(lambda data_2020_ok: data_2020_ok.replace('#森林步道','#登山步道'), data_2020_ok))        
        
        print(data_2020_ok)
        print(data_process_1)
    #如果'#森林步道' 跟 '#登山步道'，一起出現時使用，經過檢查暫時還沒有出現這種情況    
    #elif '#森林步道' in  data_2020_ok[0] and '#登山步道' in  data_2020_ok[0]:
    #    print(i)
    #    print('have_森林步道_process')
    #    data_process_1 = list(map(lambda data_2020_ok: data_2020_ok.replace('#登山步道',''), data_2020_ok))        
    #    data_process_1 = list(map(lambda data_process_1: data_process_1.replace('#森林步道','#登山步道'), data_process_1))                
    #    print(data_2020_ok)
    #    print(data_process_1)        
        
    elif '#藝術' in  data_2020_ok[0]:
        print(i)
        print('have_藝術_process')
        data_process_1 = list(map(lambda data_2020_ok: data_2020_ok.replace('#藝術','#看展覽'), data_2020_ok))  
        data_process_1 = list(map(lambda data_process_1: data_process_1.replace('#水上活動','#夏天戲水'), data_process_1))
        
        
        print(data_2020_ok)
        print(data_process_1) 

        
    elif '#水上活動' in  data_2020_ok[0] and '#夏天戲水' in  data_2020_ok[0]:
        print(i)
        print('have_水上活動_process_1')
        data_process_1 = list(map(lambda data_2020_ok: data_2020_ok.replace('#夏天戲水',''), data_2020_ok))        
        data_process_1 = list(map(lambda data_process_1: data_process_1.replace('#水上活動','#夏天戲水'), data_process_1))
        data_process_1 = list(map(lambda data_process_1: data_process_1.replace('#海灣旅遊','#看海景'), data_process_1))
        

        print(data_2020_ok)
        print(data_process_1)  
        
    elif '#水上活動' in  data_2020_ok[0]:
        print(i)
        print('have_水上活動_process_2')
        data_process_1 = list(map(lambda data_2020_ok: data_2020_ok.replace('#水上活動','#夏天戲水'), data_2020_ok))        

        print(data_2020_ok)
        print(data_process_1)        
    elif '#吃海鮮' in  data_2020_ok[0]:
        print(i)
        print('have_吃海鮮_process')
        data_process_1 = list(map(lambda data_2020_ok: data_2020_ok.replace('#吃海鮮','#非吃不可'), data_2020_ok))          
        print(data_2020_ok)
        print(data_process_1)    
        
    elif '#海灣旅遊' in  data_2020_ok[0]:
        print(i)
        print('have_海灣旅遊_process')
        data_process_1 = list(map(lambda data_2020_ok: data_2020_ok.replace('#海灣旅遊','#看海景'), data_2020_ok))          
        print(data_2020_ok)
        print(data_process_1)
        
    elif '#國家公園' in  data_2020_ok[0]:
        print(i)
        print('have_國家公園_process')
        data_process_1 = list(map(lambda data_2020_ok: data_2020_ok.replace('#國家公園','#國家風景區'), data_2020_ok))          
        print(data_2020_ok)
        print(data_process_1)        
        
    else :
        print(i)
        print('not have')
        #print(data_2020_ok)
# Out:
# HBox(children=(FloatProgress(value=0.0, max=755.0), HTML(value='')))
# 0
# not have
# 1
# not have
# 2
# not have
# 3
# not have
# 4
# have_打卡熱點_process_3
# ['#網美必拍#夏天戲水#單車漫遊#逛老街']
# ['#打卡熱點#夏天戲水#單車漫遊#逛老街']
# 5
# have_國家公園_process
# ['#賞花#生態體驗#登山步道#泡溫泉#國家公園']
# ['#賞花#生態體驗#登山步道#泡溫泉#國家風景區']
# 6
# not have
# 7
# not have
# 8
# not have
# 9
# not have
# 10
# not have
# 11
# not have
# 12
# not have
# 13
# not have
# 14
# not have
# 15
# not have
# 16
# not have
# 17
# not have
# 18
# not have
# 19
# not have
# 20
# not have
# 21
# not have
# 22
# not have
# 23
# have_水上活動_process_1
# ['#水上活動#夏天戲水#無障礙#迎曙光']
# ['#夏天戲水#無障礙#迎曙光']
# 24
# not have
# 25
# not have
# 26
# have_國家公園_process
# ['#生態體驗#地質奇觀#夏天戲水#國家公園']
# ['#生態體驗#地質奇觀#夏天戲水#國家風景區']
# 27
# have_國家公園_process
# ['#生態體驗#登山步道#國家公園']
# ['#生態體驗#登山步道#國家風景區']
# 28
# not have
# 29
# not have
# 30
# not have
# 31
# have_海灣旅遊_process
# ['#無障礙#單車漫遊#夏天戲水#海灣旅遊#國家風景區']
# ['#無障礙#單車漫遊#夏天戲水#看海景#國家風景區']
# 32
# not have
# 33
# not have
# 34
# not have
# 35
# not have
# 36
# have_藝術_process
# ['#浪漫約會#生態體驗#藝術']
# ['#浪漫約會#生態體驗#看展覽']
# 37
# not have
# 38
# have_森林步道_process
# ['#森林步道#生態體驗#打卡熱點']
# ['#登山步道#生態體驗#打卡熱點']
# 39
# not have
# 40
# not have
# 41
# have_森林步道_process
# ['#賞花#迎曙光#森林步道#無障礙']
# ['#賞花#迎曙光#登山步道#無障礙']
# 42
# not have
# 43
# not have
# 44
# not have
# 45
# not have
# 46
# not have
# 47
# not have
# 48
# not have
# 49
# not have
# 50
# have_森林步道_process
# ['#森林步道#賞花']
# ['#登山步道#賞花']
# 51
# not have
# 52
# not have
# 53
# not have
# 54
# not have
# 55
# not have
# 56
# not have
# 57
# not have
# 58
# not have
# 59
# not have
# 60
# have_國家公園_process
# ['#登山步道#生態體驗#國家公園']
# ['#登山步道#生態體驗#國家風景區']
# 61
# not have
# 62
# not have
# 63
# not have
# 64
# have_森林步道_process
# ['#森林步道#泡溫泉#生態體驗']
# ['#登山步道#泡溫泉#生態體驗']
# 65
# not have
# 66
# have_打卡熱點_process_3
# 0
# 67
# have_藝術_process
# ['#博物館#藝術']
# ['#博物館#看展覽']
# 68
# have_森林步道_process
# ['#生態體驗#森林步道#賞花']
# ['#生態體驗#登山步道#賞花']
# 69
# not have
# 70
# not have
# 71
# not have
# 72
# not have
# 73
# not have
# 74
# not have
# 75
# not have
# 76
# not have
# 77
# not have
# 78
# have_森林步道_process
# ['#賞花#迎曙光#無障礙#森林步道#國家風景區']
# ['#賞花#迎曙光#無障礙#登山步道#國家風景區']
# 79
# not have
# 80
# not have
# 81
# not have
# 82
# not have
# 83
# not have
# 84
# have_吃海鮮_process
# ['#吃海鮮#看海景#親子共遊']
# ['#非吃不可#看海景#親子共遊']
# 85
# not have
# 86
# not have
# 87
# not have
# 88
# not have
# 89
# have_森林步道_process
# ['#森林步道#生態體驗#迎曙光#賞花']
# ['#登山步道#生態體驗#迎曙光#賞花']
# 90
# have_打卡熱點_process_1
# ['#打卡熱點#網美必拍#單車漫遊#親子共遊']
# ['#打卡熱點#單車漫遊#親子共遊']
# 91
# not have
# 92
# not have
# 93
# not have
# 94
# have_吃海鮮_process
# ['#看海景#打卡熱點#吃海鮮']
# ['#看海景#打卡熱點#非吃不可']
# 95
# not have
# 96
# not have
# 97
# not have
# 98
# have_水上活動_process_1
# ['#水上活動#夏天戲水#無障礙#海灣旅遊#親子共遊']
# ['#夏天戲水#無障礙#看海景#親子共遊']
# 99
# not have
# 100
# not have
# 101
# not have
# 102
# not have
# 103
# have_森林步道_process
# ['#生態體驗#森林步道#觀景平台#親子共遊']
# ['#生態體驗#登山步道#觀景平台#親子共遊']
# 104
# have_水上活動_process_2
# ['#打卡熱點#水上活動#泡溫泉#生態體驗']
# ['#打卡熱點#夏天戲水#泡溫泉#生態體驗']
# 105
# not have
# 106
# not have
# 107
# not have
# 108
# not have
# 109
# not have
# 110
# not have
# 111
# not have
# 112
# not have
# 113
# not have
# 114
# not have
# 115
# not have
# 116
# not have
# 117
# not have
# 118
# not have
# 119
# not have
# 120
# not have
# 121
# not have
# 122
# not have
# 123
# have_藝術_process
# ['#藝術#打卡熱點']
# ['#看展覽#打卡熱點']
# 124
# not have
# 125
# not have
# 126
# not have
# 127
# not have
# 128
# have_打卡熱點_process_1
# ['#博物館#看展覽#打卡熱點#網美必拍']
# ['#博物館#看展覽#打卡熱點']
# 129
# not have
# 130
# not have
# 131
# not have
# 132
# not have
# 133
# not have
# 134
# not have
# 135
# not have
# 136
# not have
# 137
# not have
# 138
# not have
# 139
# not have
# 140
# not have
# 141
# not have
# 142
# not have
# 143
# have_打卡熱點_process_3
# 0
# 144
# not have
# 145
# not have
# 146
# not have
# 147
# not have
# 148
# have_海灣旅遊_process
# ['#親子共遊#夏天戲水#海灣旅遊']
# ['#親子共遊#夏天戲水#看海景']
# 149
# have_森林步道_process
# ['#地質奇觀#森林步道']
# ['#地質奇觀#登山步道']
# 150
# not have
# 151
# not have
# 152
# not have
# 153
# not have
# 154
# not have
# 155
# not have
# 156
# not have
# 157
# not have
# 158
# have_打卡熱點_process_1
# ['#打卡熱點#地質奇觀#網美必拍#觀景平台']
# ['#打卡熱點#地質奇觀#觀景平台']
# 159
# not have
# 160
# not have
# 161
# not have
# 162
# not have
# 163
# have_藝術_process
# ['#賞花#藝術']
# ['#賞花#看展覽']
# 164
# not have
# 165
# not have
# 166
# not have
# 167
# not have
# 168
# not have
# 169
# not have
# 170
# not have
# 171
# not have
# 172
# not have
# 173
# not have
# 174
# have_海灣旅遊_process
# ['#親子共遊#夏天戲水#海灣旅遊#無障礙']
# ['#親子共遊#夏天戲水#看海景#無障礙']
# 175
# have_海灣旅遊_process
# ['#海灣旅遊']
# ['#看海景']
# 176
# not have
# 177
# not have
# 178
# not have
# 179
# not have
# 180
# not have
# 181
# not have
# 182
# not have
# 183
# not have
# 184
# not have
# 185
# not have
# 186
# not have
# 187
# not have
# 188
# not have
# 189
# not have
# 190
# not have
# 191
# not have
# 192
# not have
# 193
# have_森林步道_process
# ['#森林步道#親子共遊#生態體驗']
# ['#登山步道#親子共遊#生態體驗']
# 194
# not have
# 195
# not have
# 196
# not have
# 197
# have_水上活動_process_2
# ['#單車漫遊#生態體驗#水上活動']
# ['#單車漫遊#生態體驗#夏天戲水']
# 198
# have_藝術_process
# ['#無障礙#藝術']
# ['#無障礙#看展覽']
# 199
# not have
# 200
# not have
# 201
# not have
# 202
# have_藝術_process
# ['#打卡熱點#藝術']
# ['#打卡熱點#看展覽']
# 203
# not have
# 204
# have_森林步道_process
# ['#生態體驗#森林步道']
# ['#生態體驗#登山步道']
# 205
# have_藝術_process
# ['#博物館#藝術']
# ['#博物館#看展覽']
# 206
# not have
# 207
# not have
# 208
# have_海灣旅遊_process
# ['#海灣旅遊#夏天戲水#打卡熱點']
# ['#看海景#夏天戲水#打卡熱點']
# 209
# not have
# 210
# not have
# 211
# not have
# 212
# not have
# 213
# not have
# 214
# not have
# 215
# not have
# 216
# have_打卡熱點_process_3
# 0
# 217
# not have
# 218
# not have
# 219
# not have
# 220
# not have
# 221
# have_森林步道_process
# ['#森林步道#生態體驗']
# ['#登山步道#生態體驗']
# 222
# not have
# 223
# not have
# 224
# have_藝術_process
# ['#看展覽#博物館#藝術#親子共遊']
# ['#看展覽#博物館#看展覽#親子共遊']
# 225
# not have
# 226
# not have
# 227
# not have
# 228
# not have
# 229
# have_海灣旅遊_process
# ['#地質奇觀#打卡熱點#海灣旅遊']
# ['#地質奇觀#打卡熱點#看海景']
# 230
# not have
# 231
# not have
# 232
# not have
# 233
# not have
# 234
# not have
# 235
# not have
# 236
# have_森林步道_process
# ['#森林步道#泡溫泉#生態體驗']
# ['#登山步道#泡溫泉#生態體驗']
# 237
# not have
# 238
# not have
# 239
# not have
# 240
# not have
# 241
# not have
# 242
# have_森林步道_process
# ['#生態體驗#賞花#森林步道']
# ['#生態體驗#賞花#登山步道']
# 243
# not have
# 244
# have_藝術_process
# ['#藝術#親子共遊#看展覽']
# ['#看展覽#親子共遊#看展覽']
# 245
# have_打卡熱點_process_1
# ['#博物館#打卡熱點#網美必拍#看展覽']
# ['#博物館#打卡熱點#看展覽']
# 246
# have_森林步道_process
# ['#泡溫泉#生態體驗#森林步道']
# ['#泡溫泉#生態體驗#登山步道']
# 247
# not have
# 248
# not have
# 249
# not have
# 250
# not have
# 251
# not have
# 252
# not have
# 253
# not have
# 254
# not have
# 255
# have_森林步道_process
# ['#森林步道#生態體驗']
# ['#登山步道#生態體驗']
# 256
# not have
# 257
# not have
# 258
# not have
# 259
# not have
# 260
# not have
# 261
# not have
# 262
# not have
# 263
# not have
# 264
# have_打卡熱點_process_3
# 0
# 265
# have_水上活動_process_1
# ['#水上活動#夏天戲水#海灣旅遊']
# ['#夏天戲水#看海景']
# 266
# not have
# 267
# not have
# 268
# have_打卡熱點_process_3
# 0
# 269
# have_打卡熱點_process_3
# 0
# 270
# have_打卡熱點_process_3
# 0
# 271
# not have
# 272
# have_國家公園_process
# ['#古蹟巡禮#戰地文化#生態體驗#國家公園']
# ['#古蹟巡禮#戰地文化#生態體驗#國家風景區']
# 273
# not have
# 274
# have_國家公園_process
# ['#生態體驗#無障礙#國家公園']
# ['#生態體驗#無障礙#國家風景區']
# 275
# not have
# 276
# have_國家公園_process
# ['#登山步道#生態體驗#國家公園']
# ['#登山步道#生態體驗#國家風景區']
# 277
# not have
# 278
# not have
# 279
# not have
# 280
# not have
# 281
# have_藝術_process
# ['#藝術']
# ['#看展覽']
# 282
# have_打卡熱點_process_3
# 0
# 283
# not have
# 284
# not have
# 285
# not have
# 286
# have_打卡熱點_process_3
# 0
# 287
# have_藝術_process
# ['#打卡熱點#藝術#看展覽#無障礙']
# ['#打卡熱點#看展覽#看展覽#無障礙']
# 288
# not have
# 289
# not have
# 290
# not have
# 291
# not have
# 292
# not have
# 293
# not have
# 294
# not have
# 295
# not have
# 296
# not have
# 297
# not have
# 298
# have_吃海鮮_process
# ['#看海景#吃海鮮']
# ['#看海景#非吃不可']
# 299
# not have
# 300
# not have
# 301
# not have
# 302
# not have
# 303
# not have
# 304
# not have
# 305
# not have
# 306
# not have
# 307
# not have
# 308
# not have
# 309
# not have
# 310
# not have
# 311
# not have
# 312
# not have
# 313
# have_打卡熱點_process_3
# 0
# 314
# not have
# 315
# have_森林步道_process
# ['#泡溫泉#生態體驗#森林步道']
# ['#泡溫泉#生態體驗#登山步道']
# 316
# have_國家公園_process
# ['#生態體驗#登山步道#國家公園#無障礙']
# ['#生態體驗#登山步道#國家風景區#無障礙']
# 317
# not have
# 318
# not have
# 319
# have_打卡熱點_process_3
# 0
# 320
# not have
# 321
# not have
# 322
# not have
# 323
# not have
# 324
# not have
# 325
# not have
# 326
# not have
# 327
# not have
# 328
# have_打卡熱點_process_3
# 0
# 329
# not have
# 330
# not have
# 331
# not have
# 332
# not have
# 333
# have_吃海鮮_process
# ['#吃海鮮#看海景#親子共遊']
# ['#非吃不可#看海景#親子共遊']
# 334
# have_藝術_process
# ['#博物館#藝術']
# ['#博物館#看展覽']
# 335
# not have
# 336
# not have
# 337
# not have
# 338
# not have
# 339
# not have
# 340
# have_藝術_process
# ['#水上活動#藝術']
# ['#夏天戲水#看展覽']
# 341
# not have
# 342
# have_吃海鮮_process
# ['#親子共遊#送夕陽#吃海鮮']
# ['#親子共遊#送夕陽#非吃不可']
# 343
# have_森林步道_process
# ['#賞花#森林步道#親子共遊']
# ['#賞花#登山步道#親子共遊']
# 344
# not have
# 345
# have_藝術_process
# ['#單車漫遊#博物館#藝術']
# ['#單車漫遊#博物館#看展覽']
# 346
# not have
# 347
# have_藝術_process
# ['#藝術#親子共遊']
# ['#看展覽#親子共遊']
# 348
# not have
# 349
# not have
# 350
# have_打卡熱點_process_3
# 0
# 351
# not have
# 352
# not have
# 353
# not have
# 354
# not have
# 355
# not have
# 356
# not have
# 357
# not have
# 358
# not have
# 359
# not have
# 360
# not have
# 361
# not have
# 362
# not have
# 363
# not have
# 364
# not have
# 365
# not have
# 366
# not have
# 367
# have_藝術_process
# ['#藝術#看展覽#打卡熱點']
# ['#看展覽#看展覽#打卡熱點']
# 368
# not have
# 369
# not have
# 370
# not have
# 371
# not have
# 372
# not have
# 373
# not have
# 374
# not have
# 375
# not have
# 376
# not have
# 377
# not have
# 378
# have_水上活動_process_2
# ['#水上活動']
# ['#夏天戲水']
# 379
# not have
# 380
# not have
# 381
# not have
# 382
# not have
# 383
# not have
# 384
# have_打卡熱點_process_3
# 0
# 385
# not have
# 386
# have_打卡熱點_process_3
# 0
# 387
# not have
# 388
# not have
# 389
# not have
# 390
# not have
# 391
# not have
# 392
# not have
# 393
# not have
# 394
# not have
# 395
# not have
# 396
# not have
# 397
# not have
# 398
# have_海灣旅遊_process
# ['#海灣旅遊#無障礙#夏天戲水#生態體驗#國家風景區']
# ['#看海景#無障礙#夏天戲水#生態體驗#國家風景區']
# 399
# not have
# 400
# not have
# 401
# not have
# 402
# not have
# 403
# not have
# 404
# not have
# 405
# not have
# 406
# not have
# 407
# not have
# 408
# not have
# 409
# not have
# 410
# not have
# 411
# not have
# 412
# not have
# 413
# have_藝術_process
# ['#藝術#看展覽#親子共遊']
# ['#看展覽#看展覽#親子共遊']
# 414
# not have
# 415
# not have
# 416
# not have
# 417
# have_水上活動_process_2
# ['#部落旅遊#生態體驗#水上活動#單車漫遊']
# ['#部落旅遊#生態體驗#夏天戲水#單車漫遊']
# 418
# not have
# 419
# not have
# 420
# have_吃海鮮_process
# ['#吃海鮮#看海景']
# ['#非吃不可#看海景']
# 421
# not have
# 422
# not have
# 423
# not have
# 424
# have_森林步道_process
# ['#夏天戲水#親子共遊#森林步道#賞花']
# ['#夏天戲水#親子共遊#登山步道#賞花']
# 425
# not have
# 426
# not have
# 427
# not have
# 428
# not have
# 429
# not have
# 430
# not have
# 431
# not have
# 432
# not have
# 433
# not have
# 434
# not have
# 435
# not have
# 436
# have_藝術_process
# ['#藝術#看展覽#親子共遊']
# ['#看展覽#看展覽#親子共遊']
# 437
# not have
# 438
# not have
# 439
# not have
# 440
# not have
# 441
# not have
# 442
# not have
# 443
# not have
# 444
# not have
# 445
# not have
# 446
# not have
# 447
# not have
# 448
# not have
# 449
# not have
# 450
# not have
# 451
# not have
# 452
# have_藝術_process
# ['#看展覽#藝術']
# ['#看展覽#看展覽']
# 453
# not have
# 454
# not have
# 455
# not have
# 456
# not have
# 457
# not have
# 458
# not have
# 459
# have_藝術_process
# ['#藝術']
# ['#看展覽']
# 460
# not have
# 461
# not have
# 462
# not have
# 463
# have_水上活動_process_2
# ['#水上活動#生態體驗#親子共遊']
# ['#夏天戲水#生態體驗#親子共遊']
# 464
# have_打卡熱點_process_3
# 0
# 465
# not have
# 466
# not have
# 467
# not have
# 468
# not have
# 469
# not have
# 470
# not have
# 471
# not have
# 472
# not have
# 473
# not have
# 474
# not have
# 475
# have_森林步道_process
# ['#生態體驗#森林步道#親子共遊']
# ['#生態體驗#登山步道#親子共遊']
# 476
# not have
# 477
# not have
# 478
# not have
# 479
# not have
# 480
# not have
# 481
# not have
# 482
# not have
# 483
# not have
# 484
# not have
# 485
# not have
# 486
# not have
# 487
# not have
# 488
# not have
# 489
# not have
# 490
# not have
# 491
# not have
# 492
# not have
# 493
# have_藝術_process
# ['#藝術#看展覽#親子共遊']
# ['#看展覽#看展覽#親子共遊']
# 494
# have_打卡熱點_process_1
# ['#打卡熱點#網美必拍#拍婚紗#燈塔']
# ['#打卡熱點#拍婚紗#燈塔']
# 495
# not have
# 496
# not have
# 497
# not have
# 498
# not have
# 499
# have_森林步道_process
# ['#生態體驗#親子共遊#森林步道']
# ['#生態體驗#親子共遊#登山步道']
# 500
# not have
# 501
# not have
# 502
# not have
# 503
# not have
# 504
# not have
# 505
# not have
# 506
# have_打卡熱點_process_3
# 0
# 507
# not have
# 508
# not have
# 509
# not have
# 510
# not have
# 511
# not have
# 512
# have_藝術_process
# ['#博物館#看展覽#藝術']
# ['#博物館#看展覽#看展覽']
# 513
# not have
# 514
# not have
# 515
# not have
# 516
# not have
# 517
# not have
# 518
# not have
# 519
# have_打卡熱點_process_3
# 0
# 520
# not have
# 521
# have_藝術_process
# ['#藝術#看展覽#親子共遊']
# ['#看展覽#看展覽#親子共遊']
# 522
# not have
# 523
# not have
# 524
# not have
# 525
# not have
# 526
# not have
# 527
# not have
# 528
# not have
# 529
# not have
# 530
# have_森林步道_process
# ['#森林步道#生態體驗']
# ['#登山步道#生態體驗']
# 531
# not have
# 532
# not have
# 533
# not have
# 534
# not have
# 535
# not have
# 536
# not have
# 537
# not have
# 538
# have_打卡熱點_process_3
# 0
# 539
# not have
# 540
# not have
# 541
# have_藝術_process
# ['#藝術']
# ['#看展覽']
# 542
# have_藝術_process
# ['#看展覽#藝術']
# ['#看展覽#看展覽']
# 543
# not have
# 544
# not have
# 545
# not have
# 546
# not have
# 547
# not have
# 548
# not have
# 549
# have_藝術_process
# ['#看展覽#博物館#藝術']
# ['#看展覽#博物館#看展覽']
# 550
# not have
# 551
# not have
# 552
# not have
# 553
# have_藝術_process
# ['#藝術#打卡熱點']
# ['#看展覽#打卡熱點']
# 554
# not have
# 555
# not have
# 556
# not have
# 557
# not have
# 558
# not have
# 559
# not have
# 560
# have_藝術_process
# ['#藝術#生態體驗#賞花']
# ['#看展覽#生態體驗#賞花']
# 561
# not have
# 562
# not have
# 563
# not have
# 564
# not have
# 565
# not have
# 566
# not have
# 567
# have_藝術_process
# ['#藝術#看展覽']
# ['#看展覽#看展覽']
# 568
# not have
# 569
# not have
# 570
# not have
# 571
# not have
# 572
# not have
# 573
# not have
# 574
# have_水上活動_process_1
# ['#夏天戲水#水上活動#生態體驗#親子共遊']
# ['#夏天戲水#生態體驗#親子共遊']
# 575
# not have
# 576
# not have
# 577
# not have
# 578
# not have
# 579
# not have
# 580
# not have
# 581
# not have
# 582
# not have
# 583
# not have
# 584
# not have
# 585
# not have
# 586
# not have
# 587
# have_打卡熱點_process_1
# ['#網美必拍#打卡熱點#親子共遊']
# ['#打卡熱點#親子共遊']
# 588
# not have
# 589
# not have
# 590
# not have
# 591
# have_藝術_process
# ['#藝術']
# ['#看展覽']
# 592
# have_打卡熱點_process_3
# 0
# 593
# not have
# 594
# not have
# 595
# not have
# 596
# not have
# 597
# not have
# 598
# not have
# 599
# not have
# 600
# not have
# 601
# not have
# 602
# not have
# 603
# not have
# 604
# not have
# 605
# not have
# 606
# have_打卡熱點_process_3
# 0
# 607
# not have
# 608
# not have
# 609
# not have
# 610
# not have
# 611
# not have
# 612
# not have
# 613
# not have
# 614
# not have
# 615
# have_打卡熱點_process_1
# ['#打卡熱點#網美必拍']
# ['#打卡熱點']
# 616
# not have
# 617
# not have
# 618
# not have
# 619
# have_打卡熱點_process_3
# 0
# 620
# have_藝術_process
# ['#打卡熱點#看展覽#藝術']
# ['#打卡熱點#看展覽#看展覽']
# 621
# not have
# 622
# have_吃海鮮_process
# ['#送夕陽#吃海鮮#看海景']
# ['#送夕陽#非吃不可#看海景']
# 623
# not have
# 624
# not have
# 625
# not have
# 626
# not have
# 627
# have_吃海鮮_process
# ['#賞夜景#單車漫遊#觀景平台#吃海鮮']
# ['#賞夜景#單車漫遊#觀景平台#非吃不可']
# 628
# not have
# 629
# not have
# 630
# have_打卡熱點_process_3
# 0
# 631
# not have
# 632
# not have
# 633
# have_打卡熱點_process_3
# 0
# 634
# have_吃海鮮_process
# ['#親子共遊#賞夜景#吃海鮮']
# ['#親子共遊#賞夜景#非吃不可']
# 635
# not have
# 636
# have_吃海鮮_process
# ['#送夕陽#吃海鮮#看海景#親子共遊']
# ['#送夕陽#非吃不可#看海景#親子共遊']
# 637
# not have
# 638
# not have
# 639
# not have
# 640
# have_打卡熱點_process_3
# ['#無障礙#夏天戲水#吃海鮮#網美必拍']
# ['#無障礙#夏天戲水#非吃不可#打卡熱點']
# 641
# have_打卡熱點_process_1
# ['#無障礙#打卡熱點#網美必拍#單車漫遊']
# ['#無障礙#打卡熱點#單車漫遊']
# 642
# not have
# 643
# have_吃海鮮_process
# ['#非吃不可#吃海鮮#看海景']
# ['#非吃不可#非吃不可#看海景']
# 644
# not have
# 645
# have_打卡熱點_process_3
# 0
# 646
# not have
# 647
# not have
# 648
# not have
# 649
# not have
# 650
# not have
# 651
# not have
# 652
# not have
# 653
# not have
# 654
# not have
# 655
# not have
# 656
# not have
# 657
# have_打卡熱點_process_3
# 0
# 658
# not have
# 659
# not have
# 660
# not have
# 661
# not have
# 662
# have_吃海鮮_process
# ['#無障礙#吃海鮮']
# ['#無障礙#非吃不可']
# 663
# have_打卡熱點_process_3
# 0
# 664
# have_打卡熱點_process_3
# 0
# 665
# not have
# 666
# not have
# 667
# not have
# 668
# have_打卡熱點_process_3
# 0
# 669
# not have
# 670
# not have
# 671
# not have
# 672
# not have
# 673
# not have
# 674
# not have
# 675
# not have
# 676
# not have
# 677
# have_打卡熱點_process_3
# 0
# 678
# not have
# 679
# not have
# 680
# not have
# 681
# have_打卡熱點_process_3
# 0
# 682
# not have
# 683
# have_打卡熱點_process_3
# 0
# 684
# not have
# 685
# not have
# 686
# not have
# 687
# not have
# 688
# not have
# 689
# not have
# 690
# not have
# 691
# have_水上活動_process_2
# ['#無障礙#水上活動']
# ['#無障礙#夏天戲水']
# 692
# not have
# 693
# not have
# 694
# not have
# 695
# not have
# 696
# not have
# 697
# not have
# 698
# not have
# 699
# not have
# 700
# not have
# 701
# have_打卡熱點_process_3
# 0
# 702
# not have
# 703
# not have
# 704
# not have
# 705
# not have
# 706
# have_打卡熱點_process_3
# 0
# 707
# have_打卡熱點_process_3
# ['#無障礙#水上活動#夏天戲水#網美必拍']
# ['#無障礙#夏天戲水#打卡熱點']
# 708
# not have
# 709
# not have
# 710
# not have
# 711
# not have
# 712
# not have
# 713
# not have
# 714
# not have
# 715
# not have
# 716
# not have
# 717
# not have
# 718
# not have
# 719
# not have
# 720
# not have
# 721
# not have
# 722
# not have
# 723
# not have
# 724
# have_藝術_process
# ['#無障礙#親子共遊#藝術']
# ['#無障礙#親子共遊#看展覽']
# 725
# not have
# 726
# not have
# 727
# not have
# 728
# not have
# 729
# not have
# 730
# not have
# 731
# not have
# 732
# not have
# 733
# have_打卡熱點_process_3
# 0
# 734
# not have
# 735
# not have
# 736
# not have
# 737
# not have
# 738
# not have
# 739
# not have
# 740
# not have
# 741
# not have
# 742
# have_打卡熱點_process_3
# 0
# 743
# not have
# 744
# not have
# 745
# not have
# 746
# not have
# 747
# not have
# 748
# not have
# 749
# not have
# 750
# not have
# 751
# not have
# 752
# not have
# 753
# not have
# 754
# not have
